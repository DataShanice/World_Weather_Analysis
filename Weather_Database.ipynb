# %% [markdown]
# # Challange Part 1: Get the weather description and the amount of precipitation  for each city.

# %%
from citipy import citipy
import numpy as np

import pandas as pd

# %%
# Create a set or random Latitudes and Longitude combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding cities 
cities = []

# Identify the nearest city for each latitude and longitude comnbination


for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique then add it to cities list. 
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 626

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /Users/shanicebrown/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (2.24.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/shanicebrown/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/shanicebrown/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from requests) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /Users/shanicebrown/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from requests) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/shanicebrown/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from requests) (2020.6.20)

# %%
# Import the request library 

import requests 
from datetime import datetime 

from config import weather_api_key

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# %%
# List of city data 
city_data = []

#Print to logger
print("Beginning Data Retrieval")
print("-" * 25)

# Create a counter 
record_count = 1
set_count = 1
for index, city in enumerate(cities):
    
    # Group cities in set of 50 for logging
    if(index % 50 == 0 and index >= 50):
        set_count += 1 
        record_count = 1 
        
# Create endpoint url 

    city_url = f'{url}&q={city.replace(" ", "+")}'
    
    print(f"Processing Record {record_count} of Set {set_count} |{city}")
    
    record_count += 1 
    
    try:
        city_weather = requests.get(city_url).json()
        #print(city_url)
        #Parse the max temp, humidity and cloudiness

        city_lat = city_weather["coord"]["lat"] 
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
    except:
        print("Key Error")
        
   
    try:
            city_rain_inches = city_weather["rain"]["1h"]
     
           
    except:
             city_rain_inches = 0
            
    try: 
            city_snow_inches = city_weather["rain"]["1h"]
        
            city_snow_inches = 0 

            
    # Append the city information into city_data 
    

            city_data.append(
        { 
            "city": city,
            "Lat" : city_lat,
            "Lng" : city_lng,
            "Max Temp" : city_max_temp,
            "Current Description": city_weather_description,
            "Rain (inches)" : city_rain_inches,
            "Snow (inches)" : city_snow_inches,
            "Humidity" : city_humidity,
            "Cloudiness" : city_clouds,
            "Wind Speed" : city_wind,
            "Country" : city_country
        })
    

    except:
        print("City not found. Skipping....")
        pass
    
    # Indicate that the Data Loading is complete
    
    print("-" * 20)
    print("Data Retrieval Complete")
    print("-" * 20)
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 |yellowknife
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 2 of Set 1 |acapulco
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 3 of Set 1 |dikson
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 4 of Set 1 |atuona
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 5 of Set 1 |kapaa
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 6 of Set 1 |puerto ayora
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 7 of Set 1 |grindavik
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 8 of Set 1 |satitoa
# Key Error
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 9 of Set 1 |chapais
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 10 of Set 1 |hermanus
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 11 of Set 1 |mataura
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 12 of Set 1 |rikitea
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 13 of Set 1 |mahon
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 14 of Set 1 |ribeira grande
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 15 of Set 1 |avarua
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 16 of Set 1 |esperance
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 17 of Set 1 |caravelas
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 18 of Set 1 |chuy
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 19 of Set 1 |arica
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 20 of Set 1 |castro
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 21 of Set 1 |ushuaia
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 22 of Set 1 |punta arenas
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 23 of Set 1 |bredasdorp
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 24 of Set 1 |paita
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 25 of Set 1 |albany
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 26 of Set 1 |phrai bung
# Key Error
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 27 of Set 1 |mercedes
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 28 of Set 1 |hobart
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 29 of Set 1 |barrow
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 30 of Set 1 |upernavik
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 31 of Set 1 |hilo
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 32 of Set 1 |new norfolk
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 33 of Set 1 |blackwater
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 34 of Set 1 |mahebourg
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 35 of Set 1 |comodoro rivadavia
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 36 of Set 1 |port elizabeth
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 37 of Set 1 |strezhevoy
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 38 of Set 1 |olafsvik
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 39 of Set 1 |belogradcik
# Key Error
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 40 of Set 1 |taolanaro
# Key Error
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 41 of Set 1 |dzhida
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 42 of Set 1 |khudumelapye
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 43 of Set 1 |adelaide
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 44 of Set 1 |belyy yar
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 45 of Set 1 |bluff
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 46 of Set
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 2 of Set 13 |porto de moz
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 3 of Set 13 |kuminskiy
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 4 of Set 13 |hanover
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 5 of Set 13 |adrar
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 6 of Set 13 |xiaoweizhai
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 7 of Set 13 |half moon bay
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 8 of Set 13 |coquimbo
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 9 of Set 13 |dudinka
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 10 of Set 13 |guiren
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 11 of Set 13 |visnes
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 12 of Set 13 |bodo
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 13 of Set 13 |eyl
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 14 of Set 13 |sokoni
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 15 of Set 13 |deputatskiy
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 16 of Set 13 |barra do corda
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 17 of Set 13 |kolpashevo
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 18 of Set 13 |ternate
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 19 of Set 13 |sovetskiy
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 20 of Set 13 |francisco sa
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 21 of Set 13 |madingou
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 22 of Set 13 |naze
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 23 of Set 13 |aqtobe
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 24 of Set 13 |kananga
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 25 of Set 13 |saint-joseph
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------
# Processing Record 26 of Set 13 |assiniboia
# City not found. Skipping....
# --------------------
# Data Retrieval Complete
# --------------------

# %%
len(city_data)
# Out:
# 66

# %%
# convert list of dictionaries to a pandas Dataframe
city_data_df  = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              city    Lat     Lng  Max Temp Current Description  Rain (inches)  \
# 0  port elizabeth -33.92   25.57     48.20          light rain           0.48
# 1          faanui -16.48 -151.75     79.66          light rain           0.40
# 2            ugra  54.78   34.33     54.64       moderate rain           1.29
# 3         jucuapa  13.52  -88.38     91.40          light rain           0.75
# 4     port alfred -33.59   26.89     51.31          light rain           0.29
# 5      nanortalik  60.14  -45.24     41.22          light rain           0.21
# 6       busselton -33.65  115.33     57.00          light rain           0.13
# 7        flinders -34.58  150.86     59.00          light rain           0.14
# 8           giyon   8.53   37.98     56.52          light rain           0.36
# 9      butaritari   3.07  172.79     77.86          light rain           0.16
#
#    Snow (inches)  Humidity  Cloudiness  Wind Speed Country
# 0              0        76          89       10.29      ZA
# 1              0        77           0        5.70      PF
# 2              0        97         100       16.53      RU
# 3              0        63          64        1.92      SV
# 4              0        73          76       15.17      ZA
# 5              0        94         100        2.30      GL
# 6              0        84          89       14.58      AU
# 7              0        66         100       17.00      AU
# 8              0        88          65        1.41      ET
# 9              0        81         100        4.90      KI

# %%
city_data_df.dtypes
# Out:
# city                    object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Current Description     object
# Rain (inches)          float64
# Snow (inches)            int64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Country                 object
# dtype: object

# %%
raining_cities = city_data_df.loc[city_data_df["Rain (inches)"] > 0]
raining_cities.head()
# Out:
#              city    Lat     Lng  Max Temp Current Description  Rain (inches)  \
# 0  port elizabeth -33.92   25.57     48.20          light rain           0.48
# 1          faanui -16.48 -151.75     79.66          light rain           0.40
# 2            ugra  54.78   34.33     54.64       moderate rain           1.29
# 3         jucuapa  13.52  -88.38     91.40          light rain           0.75
# 4     port alfred -33.59   26.89     51.31          light rain           0.29
#
#    Snow (inches)  Humidity  Cloudiness  Wind Speed Country
# 0              0        76          89       10.29      ZA
# 1              0        77           0        5.70      PF
# 2              0        97         100       16.53      RU
# 3              0        63          64        1.92      SV
# 4              0        73          76       15.17      ZA

# %%
snowing_cities = city_data_df.loc[city_data_df["Snow (inches)"] > 0]
snowing_cities.head()
# Out:
# Empty DataFrame
# Columns: [city, Lat, Lng, Max Temp, Current Description, Rain (inches), Snow (inches), Humidity, Cloudiness, Wind Speed, Country]
# Index: []

# %%
# Create the output file (CSV)

city_data_df.to_csv("city_data.csv")
