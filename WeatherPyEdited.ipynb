# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# ushuaia ar
# taolanaro mg
# ushuaia ar
# cabo san lucas mx
# half moon bay us
# hermanus za
# mataura pf
# monte alegre br
# busselton au
# raisinghnagar in
# olinda br
# vanavara ru
# lomza pl
# avarua ck
# sault sainte marie ca
# carnarvon au
# east london za
# husavik is
# cabo san lucas mx
# busselton au
# namatanai pg
# castro cl
# albany au
# belmonte br
# ardalstangen no
# erzin ru
# waitati nz
# rikitea pf
# hithadhoo mv
# vavoua ci
# punta arenas cl
# yerbogachen ru
# port alfred za
# chokurdakh ru
# batemans bay au
# atuona pf
# mataura pf
# torbay ca
# alofi nu
# metro id
# atuona pf
# maarianhamina fi
# busselton au
# santiago del estero ar
# goderich sl
# jamestown sh
# vredendal za
# carnarvon au
# ushuaia ar
# boende cd
# hirara jp
# codrington ag
# chuy uy
# mataura pf
# cherskiy ru
# avera pf
# saldanha za
# pucallpa pe
# hermanus za
# attawapiskat ca
# tigzirt dz
# clyde river ca
# nyuksenitsa ru
# labuhan id
# sao filipe cv
# luwuk id
# chokurdakh ru
# albany au
# tiksi ru
# gazanjyk tm
# kalagarh in
# ushuaia ar
# mataura pf
# bluff nz
# utete tz
# ushuaia ar
# bambous virieux mu
# arraial do cabo br
# barrow us
# khatanga ru
# busselton au
# katobu id
# cape town za
# kadykchan ru
# port alfred za
# hilo us
# rikitea pf
# vaini to
# mandalgovi mn
# esperance au
# rikitea pf
# jamestown sh
# vaini to
# bredasdorp za
# upernavik gl
# mairana bo
# newport us
# new norfolk au
# atuona pf
# khatanga ru
# sao filipe cv
# senanga zm
# rikitea pf
# dikson ru
# sola vu
# pevek ru
# nerja es
# charters towers au
# puerto leguizamo co
# albany au
# hermanus za
# fortuna us
# dikson ru
# cape town za
# hermanus za
# westerland de
# beyneu kz
# boa vista br
# punta arenas cl
# taolanaro mg
# ishigaki jp
# busselton au
# taolanaro mg
# new norfolk au
# puerto ayora ec
# barentsburg sj
# port elizabeth za
# victoria sc
# kodiak us
# atuona pf
# puerto del rosario es
# ushuaia ar
# kajaani fi
# hasaki jp
# norman wells ca
# samusu ws
# tuktoyaktuk ca
# norman wells ca
# ushuaia ar
# rikitea pf
# gushikawa jp
# albany au
# porto seguro br
# hithadhoo mv
# grand-santi gf
# nizhneyansk ru
# ilulissat gl
# punta arenas cl
# puerto ayora ec
# jamestown sh
# dikson ru
# samusu ws
# kavant in
# salalah om
# castro cl
# charlestown kn
# bluff nz
# syracuse it
# trairi br
# vaini to
# salta ar
# puerto ayora ec
# havre-saint-pierre ca
# hermanus za
# nikolskoye ru
# rikitea pf
# areosa pt
# rikitea pf
# rikitea pf
# taoudenni ml
# hit iq
# lebu cl
# pisco pe
# isangel vu
# sawakin sd
# altamira br
# amderma ru
# port alfred za
# puerto escondido mx
# bluff nz
# albany au
# butaritari ki
# dolbeau ca
# kukuna sl
# hilo us
# broken hill au
# illoqqortoormiut gl
# vaini to
# dingle ie
# yanam in
# pangnirtung ca
# komsomolskiy ru
# bloemfontein za
# albany au
# najran sa
# thompson ca
# barrow us
# ketchikan us
# kapaa us
# ilulissat gl
# pevek ru
# nyurba ru
# vaini to
# ankazoabo mg
# hobart au
# nome us
# bluff nz
# east london za
# longyearbyen sj
# sorong id
# vaini to
# barentsburg sj
# adrar dz
# kankon in
# busselton au
# ushuaia ar
# kapaa us
# kailua us
# fortuna us
# mataura pf
# avarua ck
# norman wells ca
# cabo san lucas mx
# bengkulu id
# southbridge nz
# awbari ly
# yantal ru
# albany au
# maghama mr
# east london za
# tabiauea ki
# kamenskoye ru
# illoqqortoormiut gl
# dikson ru
# dikson ru
# quang ngai vn
# ayagoz kz
# praia cv
# arvika se
# xining cn
# capoeiras br
# rikitea pf
# ancud cl
# ishigaki jp
# punta arenas cl
# punta arenas cl
# komsomolskiy ru
# sao filipe cv
# oranjemund na
# pisco pe
# ushuaia ar
# ust-tsilma ru
# pangnirtung ca
# poum nc
# puerto ayora ec
# saskylakh ru
# port angeles us
# cherskiy ru
# taolanaro mg
# burkhala ru
# ponta do sol cv
# gat ly
# iqaluit ca
# vaini to
# flinders au
# aykhal ru
# bluff nz
# grand forks us
# fort wayne us
# nizhneyansk ru
# cabo san lucas mx
# chuy uy
# beian cn
# souillac mu
# waitati nz
# ushuaia ar
# punta arenas cl
# cape town za
# rikitea pf
# tasiilaq gl
# dakar sn
# busselton au
# sentyabrskiy ru
# rocha uy
# atuona pf
# sao filipe cv
# isangel vu
# kupino ru
# puerto ayora ec
# avera pf
# jamestown sh
# port alfred za
# neiafu to
# lebu cl
# east london za
# paytug uz
# saint-philippe re
# labutta mm
# hermanus za
# khatanga ru
# port elizabeth za
# berlevag no
# barrow us
# hilo us
# pitimbu br
# kapaa us
# bluff nz
# cape town za
# kapaa us
# east london za
# peleduy ru
# port-gentil ga
# sur om
# leh in
# kruisfontein za
# codrington ag
# guerrero negro mx
# shache cn
# cape canaveral us
# krasnoyarsk ru
# esperance au
# male mv
# hobart au
# gobabis na
# nanortalik gl
# madaoua ne
# chokurdakh ru
# ushuaia ar
# vaini to
# hambantota lk
# busselton au
# hithadhoo mv
# ushuaia ar
# tecoanapa mx
# port elizabeth za
# nikolskoye ru
# tuktoyaktuk ca
# new norfolk au
# tazovskiy ru
# argentan fr
# abeche td
# myshkin ru
# port hueneme us
# nelson bay au
# cockburn town tc
# alta floresta br
# grand gaube mu
# lazaro cardenas mx
# albany au
# albany au
# hope mills us
# vanimo pg
# rikitea pf
# almoloya mx
# gambela et
# talcahuano cl
# san patricio mx
# punta arenas cl
# ushuaia ar
# avarua ck
# tonj sd
# longyearbyen sj
# trairi br
# hermanus za
# port lincoln au
# vagamo no
# ushuaia ar
# illoqqortoormiut gl
# albany au
# bambous virieux mu
# ahipara nz
# pingliang cn
# cape town za
# shetpe kz
# san rafael ar
# barrow us
# hobart au
# linjiang cn
# ellisras za
# zemio cf
# cape town za
# bredasdorp za
# kamenka ru
# kapaa us
# ushuaia ar
# hermanus za
# port alfred za
# saskylakh ru
# dingle ie
# thompson ca
# kofele et
# puerto leguizamo co
# am timan td
# busselton au
# garden city us
# guatemala gt
# dikson ru
# rikitea pf
# victor harbor au
# albany au
# lebu cl
# saint-philippe re
# hobyo so
# rikitea pf
# airai pw
# cabo san lucas mx
# kapaa us
# hermanus za
# grand river south east mu
# sambava mg
# torbay ca
# port alfred za
# mataura pf
# atuona pf
# naze jp
# mahebourg mu
# mujiayingzi cn
# chernyshevskiy ru
# mikhaylovka kz
# ushuaia ar
# batagay ru
# alofi nu
# marcona pe
# ambilobe mg
# sao filipe cv
# vardo no
# butaritari ki
# nyurba ru
# narsaq gl
# nizwa om
# hithadhoo mv
# vaini to
# haines junction ca
# coahuayana mx
# tasiilaq gl
# kruisfontein za
# lavrentiya ru
# rikitea pf
# panguipulli cl
# uhlove ua
# mataura pf
# husavik is
# bathsheba bb
# qaanaaq gl
# rikitea pf
# nelson bay au
# mar del plata ar
# vardo no
# butaritari ki
# hermanus za
# clyde river ca
# saleaula ws
# taolanaro mg
# ozinki ru
# mahebourg mu
# nikolskoye ru
# port alfred za
# manzhouli cn
# kuala terengganu my
# adamovka ru
# karauzyak uz
# seoul kr
# punta arenas cl
# hailun cn
# vanimo pg
# port lincoln au
# mataura pf
# albany au
# saint-philippe re
# yellowknife ca
# nemuro jp
# havre-saint-pierre ca
# mahebourg mu
# nizhneyansk ru
# kruisfontein za
# middelburg za
# hit iq
# hurghada eg
# atuona pf
# broome au
# college us
# khatanga ru
# lorengau pg
# ushuaia ar
# salym ru
# tuktoyaktuk ca
# champerico gt
# rikitea pf
# east london za
# tobermory gb
# mataura pf
# tiksi ru
# geraldton ca
# chokurdakh ru
# te anau nz
# belgrade us
# collie au
# gangotri in
# algeciras ph
# rikitea pf
# barrow us
# carnarvon au
# busselton au
# butaritari ki
# rikitea pf
# rikitea pf
# bengkulu id
# port elizabeth za
# hobart au
# hilo us
# klyuchevskiy ru
# susanville us
# belushya guba ru
# zhezkazgan kz
# paamiut gl
# bolshoye sorokino ru
# qaanaaq gl
# nemuro jp
# tiksi ru
# albany au
# illoqqortoormiut gl
# hilo us
# ilulissat gl
# kaitangata nz
# atuona pf
# kodiak us
# khairabad in
# yellowknife ca
# kudahuvadhoo mv
# albany au
# newcastle au
# vaitupu wf
# srednekolymsk ru
# salta ar
# vila velha br
# barrow us
# dikson ru
# buraydah sa
# ushuaia ar
# tsihombe mg
# victoria sc
# xadani mx
# bredasdorp za
# tuktoyaktuk ca
# sibolga id
# butaritari ki
# agara ge
# hobart au
# illoqqortoormiut gl
# flinders au
# rikitea pf
# mataura pf
# fortuna us
# esperance au
# punta arenas cl
# lompoc us
# pinillos co
# new norfolk au
# mataura pf
# palabuhanratu id
# nouadhibou mr
# punta arenas cl
# hermanus za
# saint-philippe re
# ushuaia ar
# riyadh sa
# doha qa
# dikson ru
# busselton au
# port lincoln au
# ushuaia ar
# kavieng pg
# mataura pf
# chuy uy
# bonavista ca
# kavieng pg
# ushuaia ar
# sentyabrskiy ru
# yeppoon au
# port elizabeth za
# butaritari ki
# pevek ru
# brokopondo sr
# sabha ly
# maragogi br
# norman wells ca
# ushuaia ar
# arequipa pe
# hailar cn
# mataura pf
# paamiut gl
# rikitea pf
# guerrero negro mx
# mount darwin zw
# flin flon ca
# hobart au
# tiksi ru
# san patricio mx
# chuy uy
# sinnamary gf
# mogadishu so
# sitka us
# vaini to
# humberto de campos br
# san ramon bo
# airai pw
# rudnya ru
# san carlos bo
# jamestown sh
# hobart au
# hami cn
# mataura pf
# labuhan id
# hithadhoo mv
# agirish ru
# albany au
# hobart au
# chokurdakh ru
# nuuk gl
# tsihombe mg
# cascais pt
# bluff nz
# illoqqortoormiut gl
# barentsburg sj
# harper lr
# amderma ru
# albany au
# jamestown sh
# hobart au
# saskylakh ru
# naze jp
# derzhavinsk kz
# severo-kurilsk ru
# miles city us
# samusu ws
# mahebourg mu
# taolanaro mg
# atuona pf
# carnarvon au
# mar del plata ar
# talakan ru
# chabahar ir
# yellowknife ca
# provideniya ru
# chuy uy
# maloshuyka ru
# alofi nu
# saint-joseph re
# hobart au
# mataura pf
# oga jp
# punta arenas cl
# taolanaro mg
# atuona pf
# guerrero negro mx
# sitka us
# cherskiy ru
# ilulissat gl
# mayo ca
# vaini to
# tuktoyaktuk ca
# floro no
# rikitea pf
# new norfolk au
# mar del plata ar
# rikitea pf
# owerri ng
# okha ru
# georgetown sh
# khatanga ru
# salym ru
# geraldton au
# saint-philippe re
# punta arenas cl
# bredasdorp za
# mandalgovi mn
# talaya ru
# ushuaia ar
# suntar ru
# rikitea pf
# mahebourg mu
# hermanus za
# mocuba mz
# cape town za
# bafq ir
# mataura pf
# barrow us
# astana kz
# lavrentiya ru
# qaanaaq gl
# longyearbyen sj
# naze jp
# mataura pf
# maragogi br
# cape coast gh
# vaitupu wf
# lavrentiya ru
# piran si
# tsihombe mg
# port hedland au
# khatanga ru
# faanui pf
# port elizabeth za
# yellowknife ca
# rikitea pf
# bud no
# rikitea pf
# rikitea pf
# chardara kz
# yar-sale ru
# carnarvon au
# korla cn
# saskylakh ru
# baturaja id
# saint george bm
# bubaque gw
# cherskiy ru
# ushuaia ar
# atuona pf
# castro cl
# putai tw
# cape town za
# beringovskiy ru
# provideniya ru
# saleaula ws
# kahului us
# sur om
# saskylakh ru
# mataura pf
# barrow us
# vaini to
# cape town za
# pran buri th
# mataura pf
# baghdad iq
# bluff nz
# airai pw
# zhaocheng cn
# vaini to
# laguna br
# chongwe zm
# hermanus za
# atuona pf
# cape town za
# punta arenas cl
# calabozo ve
# linhares br
# kirakira sb
# airai pw
# mantua cu
# butaritari ki
# kruisfontein za
# dikson ru
# cherskiy ru
# sao filipe cv
# saleaula ws
# alotau pg
# vao nc
# dryden ca
# provideniya ru
# port alfred za
# illoqqortoormiut gl
# castro cl
# komsomolskiy ru
# upernavik gl
# komsomolskiy ru
# victoria sc
# dingle ie
# atuona pf
# sinnamary gf
# hobart au
# ribeira grande pt
# ushuaia ar
# cidreira br
# leningradskiy ru
# rikitea pf
# saint-augustin ca
# luderitz na
# nizhneyansk ru
# barabai id
# cherskiy ru
# aitape pg
# cabo san lucas mx
# nikolskoye ru
# kibre mengist et
# artyk ru
# kirakira sb
# east london za
# mamallapuram in
# ushuaia ar
# san patricio mx
# misratah ly
# albany au
# hermanus za
# avarua ck
# dunedin nz
# barentsburg sj
# krasnoselkup ru
# leningradskiy ru
# kudahuvadhoo mv
# ushuaia ar
# illoqqortoormiut gl
# chake chake tz
# albany au
# salalah om
# iskateley ru
# neuquen ar
# cape town za
# taolanaro mg
# punta arenas cl
# barrow us
# ancud cl
# bissau gw
# punta arenas cl
# busselton au
# flin flon ca
# tuatapere nz
# sao miguel do araguaia br
# ilulissat gl
# tuktoyaktuk ca
# bud no
# pacific grove us
# albany au
# tambopata pe
# cervo es
# faanui pf
# saskylakh ru
# avarua ck
# san cristobal ec
# huarmey pe
# caravelas br
# atuona pf
# saskylakh ru
# mareeba au
# hermanus za
# butaritari ki
# mataura pf
# albany au
# hilo us
# bengkulu id
# guerrero negro mx
# ushuaia ar
# obluche ru
# upernavik gl
# baykit ru
# nsanje mw
# inhambane mz
# yellowknife ca
# jardim br
# hilo us
# nanortalik gl
# rikitea pf
# arraial do cabo br
# lorengau pg
# ushuaia ar
# yambio sd
# vaini to
# kodiak us
# saleaula ws
# castro cl
# mataura pf
# nome us
# hilo us
# jamestown sh
# pemangkat id
# port alfred za
# ancud cl
# san patricio mx
# nikolskoye ru
# luderitz na
# tsihombe mg
# kapaa us
# nouakchott mr
# hilo us
# ushuaia ar
# lompoc us
# bendigo au
# vaini to
# rovaniemi fi
# butaritari ki
# mareeba au
# hithadhoo mv
# port hardy ca
# bubaque gw
# vaitupu wf
# andenes no
# puerto ayora ec
# saint george bm
# torbay ca
# mataura pf
# rikitea pf
# sergeyevka kz
# saldanha za
# hobart au
# albany au
# gold coast au
# harindanga in
# bredasdorp za
# glenwood springs us
# barrow us
# romitan uz
# barrow us
# umzimvubu za
# madimba tz
# puerto ayora ec
# butaritari ki
# mitsamiouli km
# busselton au
# hun ly
# taolanaro mg
# galveston us
# hermanus za
# punta arenas cl
# rikitea pf
# riyadh sa
# castro cl
# hasaki jp
# jamestown sh
# new norfolk au
# tanete id
# vera cruz br
# rikitea pf
# nova ushytsya ua
# fairbanks us
# lebu cl
# destin us
# toamasina mg
# douglas us
# rikitea pf
# burica pa
# saint-francois gp
# maragogi br
# dublin us
# jalu ly
# rikitea pf
# adrar dz
# tunduru tz
# ponta delgada pt
# albany au
# cape town za
# buala sb
# rikitea pf
# lasa cn
# jalu ly
# srednekolymsk ru
# east london za
# la rioja ar
# yenagoa ng
# rikitea pf
# torbay ca
# narsaq gl
# belushya guba ru
# puerto ayora ec
# atuona pf
# havoysund no
# tuktoyaktuk ca
# severo-kurilsk ru
# tuktoyaktuk ca
# mahebourg mu
# nanortalik gl
# kapaa us
# mataura pf
# sentyabrskiy ru
# shingu jp
# illoqqortoormiut gl
# punta arenas cl
# busselton au
# tilichiki ru
# ushuaia ar
# westport ie
# punta arenas cl
# grand gaube mu
# iqaluit ca
# cape town za
# ushuaia ar
# punta arenas cl
# punta arenas cl
# mataura pf
# taos us
# esperance au
# punta arenas cl
# klaksvik fo
# srednekolymsk ru
# rikitea pf
# bluff nz
# barrow us
# karauzyak uz
# grand river south east mu
# noyon fr
# amapa br
# lavrentiya ru
# saint george bm
# grand river south east mu
# necochea ar
# bredasdorp za
# nanortalik gl
# qaanaaq gl
# rikitea pf
# norman wells ca
# arraial do cabo br
# ixtapa mx
# yellowknife ca
# antalaha mg
# ust-tsilma ru
# chokurdakh ru
# jamestown sh
# kruisfontein za
# karkaralinsk kz
# port alfred za
# vaini to
# rikitea pf
# ushuaia ar
# tuktoyaktuk ca
# tabiauea ki
# bredasdorp za
# avarua ck
# dikson ru
# bandarbeyla so
# ushuaia ar
# ust-kuyga ru
# punta arenas cl
# hermanus za
# busselton au
# pedasi pa
# amderma ru
# santa vitoria do palmar br
# laguna br
# new norfolk au
# avarua ck
# nishihara jp
# rikitea pf
# ushuaia ar
# pisco pe
# pevek ru
# busselton au
# ushuaia ar
# ponta do sol cv
# severo-kurilsk ru
# saint anthony ca
# hilo us
# bambanglipuro id
# torbay ca
# usinsk ru
# castro cl
# puerto ayora ec
# kurtalan tr
# tiksi ru
# butaritari ki
# busselton au
# ji-parana br
# havoysund no
# krasnyy chikoy ru
# broken hill au
# atuona pf
# rikitea pf
# hobart au
# punta arenas cl
# chokurdakh ru
# maldonado uy
# cape town za
# khandyga ru
# saint-philippe re
# punta arenas cl
# mataura pf
# ushuaia ar
# thompson ca
# codrington ag
# cape town za
# ponta do sol cv
# khatanga ru
# busselton au
# ushuaia ar
# broome au
# taolanaro mg
# paragominas br
# ushuaia ar
# pemangkat id
# vaini to
# albany au
# maragogi br
# upernavik gl
# hobart au
# lashio mm
# barrow us
# mar del plata ar
# souillac mu
# bluff nz
# butaritari ki
# rosario do sul br
# puerto ayora ec
# longyearbyen sj
# vostok ru
# paamiut gl
# satitoa ws
# longyearbyen sj
# taolanaro mg
# rikitea pf
# egvekinot ru
# busselton au
# victoria sc
# bambous virieux mu
# lebu cl
# albany au
# albany au
# sentyabrskiy ru
# saint george bm
# ushuaia ar
# guerrero negro mx
# atuona pf
# skalistyy ru
# jamestown sh
# rikitea pf
# barentsburg sj
# eureka us
# iquitos pe
# mataura pf
# fomboni km
# kaitangata nz
# jamestown sh
# bambous virieux mu
# hithadhoo mv
# puerto ayora ec
# bethel us
# sao filipe cv
# karaul ru
# thompson ca
# tuktoyaktuk ca
# saskylakh ru
# bonthe sl
# kodinsk ru
# kapaa us
# avarua ck
# mataura pf
# rikitea pf
# hua hin th
# shkotovo-26 ru
# marawi sd
# murphy us
# dikson ru
# tarakan id
# hobart au
# acapulco mx
# narsaq gl
# bredasdorp za
# vao nc
# beira mz
# albany au
# airai pw
# hilo us
# barawe so
# arraial do cabo br
# nelson bay au
# porto novo cv
# hermanus za
# esfahan ir
# trelew ar
# albany au
# srivardhan in
# guerrero negro mx
# portland au
# mataura pf
# salalah om
# hilo us
# grindavik is
# hithadhoo mv
# busselton au
# elat il
# cape town za
# keti bandar pk
# valenza it
# kropotkin ru
# puerto ayora ec
# hambantota lk
# tsihombe mg
# port hedland au
# hobart au
# bluff nz
# ushuaia ar
# kattivakkam in
# baijiantan cn
# new norfolk au
# east london za
# vaini to
# hambantota lk
# hobart au
# punta arenas cl
# barentsburg sj
# abancay pe
# zinder ne
# rikitea pf
# rocha uy
# port elizabeth za
# yellowknife ca
# ushuaia ar
# carnarvon au
# puerto ayora ec
# havoysund no
# haapu pf
# ushuaia ar
# panama city us
# guane cu
# airai pw
# sinnamary gf
# mataura pf
# taolanaro mg
# carballo es
# olga ru
# adrar dz
# barentsburg sj
# taolanaro mg
# caxito ao
# hermanus za
# villa oliva py
# wonthaggi au
# choucheng cn
# taolanaro mg
# luderitz na
# hobart au
# bluff nz
# batemans bay au
# clovis us
# mar del plata ar
# bambous virieux mu
# qaanaaq gl
# mahebourg mu
# meyungs pw
# busselton au
# sosnovo ru
# mar del plata ar
# te anau nz
# pacific grove us
# tsabong bw
# roald no
# ushuaia ar
# airai pw
# taolanaro mg
# owando cg
# ancud cl
# vaini to
# illoqqortoormiut gl
# saint-francois gp
# lebu cl
# vila franca do campo pt
# coquimbo cl
# ribeira grande pt
# chase ca
# touros br
# morondava mg
# tuktoyaktuk ca
# port alfred za
# jamestown sh
# rikitea pf
# kodinsk ru
# vaini to
# pali in
# albany au
# cidreira br
# husavik is
# punta arenas cl
# fukue jp
# tabou ci
# towada jp
# dikson ru
# busselton au
# tabiauea ki
# ouesso cg
# barentsburg sj
# butaritari ki
# beausejour ca
# busselton au
# hithadhoo mv
# mount isa au
# rikitea pf
# gewane et
# broken hill au
# oudtshoorn za
# shimoda jp
# korla cn
# kapoeta sd
# bluff nz
# rikitea pf
# ilebo cd
# mys shmidta ru
# abha sa
# san patricio mx
# hermanus za
# kapaa us
# changli cn
# meyungs pw
# parrita cr
# dikson ru
# narsaq gl
# chabahar ir
# toora-khem ru
# souillac mu
# kapaa us
# terrace bay ca
# huangzhou cn
# amderma ru
# busselton au
# bayevo ru
# provideniya ru
# cidreira br
# banda aceh id
# mount gambier au
# turukhansk ru
# paamiut gl
# tiksi ru
# sitka us
# mar del plata ar
# bandarbeyla so
# nizhneyansk ru
# ancud cl
# bonavista ca
# nikolskoye ru
# viligili mv
# mar del plata ar
# hammelburg de
# coburg de
# ribeira grande pt
# fortuna us
# sorong id
# meulaboh id
# qaanaaq gl
# sentyabrskiy ru
# mataura pf
# ola ru
# atuona pf
# idrinskoye ru
# ciudad bolivar ve
# camana pe
# rikitea pf
# lompoc us
# san jose bo
# kars tr
# cabo san lucas mx
# taolanaro mg
# rikitea pf
# barrow us
# mogadishu so
# pahrump us
# mao td
# hasaki jp
# emerald au
# kapaa us
# ormara pk
# punta arenas cl
# dhidhdhoo mv
# fort-shevchenko kz
# hobart au
# pontianak id
# saleaula ws
# vardo no
# katsuura jp
# east london za
# khatanga ru
# port alfred za
# migori ke
# amursk ru
# georgetown sh
# butaritari ki
# yashkul ru
# constitucion mx
# melita ca
# joshimath in
# salalah om
# ushuaia ar
# ushuaia ar
# kapaa us
# bandarbeyla so
# rikitea pf
# salinopolis br
# lebu cl
# busselton au
# sveti nikole mk
# atuona pf
# kupang id
# port alfred za
# barbar sd
# busselton au
# lebu cl
# puerto narino co
# nizhneyansk ru
# lavrentiya ru
# zaigrayevo ru
# husavik is
# coihaique cl
# burnie au
# vaitupu wf
# ancud cl
# cherskiy ru
# necochea ar
# kribi cm
# malibu us
# jamestown sh
# hobart au
# vardo no
# kidal ml
# faanui pf
# ixtapa mx
# broken hill au
# bredasdorp za
# barentsburg sj
# rikitea pf
# torbay ca
# cape town za
# carbonia it
# castro cl
# ancud cl
# port alfred za
# punta arenas cl
# port alfred za
# chuy uy
# mayumba ga
# yellowknife ca
# vardo no
# bredasdorp za
# el cobre cu
# huarmey pe
# kavieng pg
# avarua ck
# yellowknife ca
# taolanaro mg
# butaritari ki
# hermanus za
# vaitupu wf
# mataura pf
# thompson ca
# kamenskoye ru
# phonhong la
# alugan ph
# manakara mg
# arraial do cabo br
# bethel us
# vangaindrano mg
# bengkulu id
# mobaye cf
# puerto ayora ec
# mar del plata ar
# ulladulla au
# great bend us
# barrow us
# mayo ca
# busselton au
# bluff nz
# paraiso mx
# bonthe sl
# chokwe mz
# kapaa us
# port alfred za
# el sauzal mx
# albany au
# sao raimundo nonato br
# wajir ke
# makung tw
# port alfred za
# moron mn
# kiruna se
# busselton au
# busselton au
# chuy uy
# nizhneyansk ru
# rikitea pf
# wanaka nz
# hobart au
# nouadhibou mr
# mar del plata ar
# albury au
# butaritari ki
# longyearbyen sj
# hobart au
# souillac mu
# georgetown sh
# atuona pf
# port blair in
# tasbuget kz
# port alfred za
# wahiawa us
# vaini to
# butaritari ki
# hailey us
# palmer us
# chernyshevskiy ru
# saint-augustin ca
# carnarvon au
# jamestown sh
# nuevo progreso mx
# vaini to
# kodiak us
# albany au
# new norfolk au
# mahebourg mu
# punta arenas cl
# avarua ck
# kropotkin ru
# lagoa pt
# agnibilekrou ci
# bayan kw
# punta arenas cl
# east london za

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 604

# %%
import requests 
requests.__version__
# Out:
# '2.22.0'

# %% [markdown]
# # Get the City Weather Data

# %%
import requests 
from datetime import datetime
import pandas as pd 
import numpy as np

from citipy import citipy

import matplotlib.pyplot as plt 

from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 630

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0743b44002d1e2474d864b1d5243b3af

# %%
city_data = []

# Print the beginning of the logging. 

print("Beginning Data Retrieval    ")
print("----------------------------")

# Create counters. 
record_count = 1 
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    
# Add 1 to record count     
    record_count +=1
        
   # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | kavaratti
# Processing Record 3 of Set 1 | georgetown
# Processing Record 4 of Set 1 | nagua
# Processing Record 5 of Set 1 | turbat
# Processing Record 6 of Set 1 | la rioja
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | clyde river
# Processing Record 9 of Set 1 | leningradskiy
# Processing Record 10 of Set 1 | lupiro
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | pittsfield
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | tuktoyaktuk
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | linapacan
# City not found. Skipping...
# Processing Record 19 of Set 1 | arraial do cabo
# Processing Record 20 of Set 1 | agadez
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | matara
# Processing Record 23 of Set 1 | lebu
# Processing Record 24 of Set 1 | marsh harbour
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | killybegs
# Processing Record 27 of Set 1 | adrar
# Processing Record 28 of Set 1 | ponta do sol
# Processing Record 29 of Set 1 | katsiveli
# City not found. Skipping...
# Processing Record 30 of Set 1 | narsaq
# Processing Record 31 of Set 1 | cadillac
# Processing Record 32 of Set 1 | barbar
# City not found. Skipping...
# Processing Record 33 of Set 1 | taguatinga
# Processing Record 34 of Set 1 | tabuk
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | geraldton
# Processing Record 37 of Set 1 | soyo
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | touros
# Processing Record 40 of Set 1 | namatanai
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | port alfred
# Processing Record 43 of Set 1 | luderitz
# Processing Record 44 of Set 1 | pacifica
# Processing Record 45 of Set 1 | ribeira grande
# Processing Record 46 of Set 1 | khabary
# Processing Record 47 of Set 1 | porto seguro
# Processing Record 48 of Set 1 | sitka
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | thompson
# Processing Record 1 of Set 2 | meadela
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 4 of Set 2 | amapa
# Processing Record 5 of Set 2 | kamiiso
# Processing Record 6 of Set 2 | kamina
# Processing Record 7 of Set 2 | cherskiy
# Processing Record 8 of Set 2 | nisia floresta
# Processing Record 9 of Set 2 | mount darwin
# Processing Record 10 of Set 2 | shenzhen
# Processing Record 11 of Set 2 | ilhabela
# Processing Record 12 of Set 2 | kodiak
# Processing Record 13 of Set 2 | itarsi
# Processing Record 14 of Set 2 | ancud
# Processing Record 15 of Set 2 | airai
# Processing Record 16 of Set 2 | saint george
# Processing Record 17 of Set 2 | subiaco
# Processing Record 18 of Set 2 | barrow
# Processing Record 19 of Set 2 | vila velha
# Processing Record 20 of Set 2 | lagoa
# Processing Record 21 of Set 2 | alimanguan
# City not found. Skipping...
# Processing Record 22 of Set 2 | henties bay
# Processing Record 23 of Set 2 | zacualpan
# Processing Record 24 of Set 2 | los llanos de aridane
# Processing Record 25 of Set 2 | teacapan
# Processing Record 26 of Set 2 | port blair
# Processing Record 27 of Set 2 | muros
# Processing Record 28 of Set 2 | ribeira brava
# Processing Record 29 of Set 2 | rafraf
# Processing Record 30 of Set 2 | ullapool
# Processing Record 31 of Set 2 | poum
# Processing Record 32 of Set 2 | bengkulu
# Processing Record 33 of Set 2 | lavrentiya
# Processing Record 34 of Set 2 | punta alta
# Processing Record 35 of Set 2 | batagay
# Processing Record 36 of Set 2 | xining
# Processing Record 37 of Set 2 | qaanaaq
# Processing Record 38 of Set 2 | saskylakh
# Processing Record 39 of Set 2 | krasnoarmeysk
# Processing Record 40 of Set 2 | hovd
# Processing Record 41 of Set 2 | magadan
# Processing Record 42 of Set 2 | saint-philippe
# Processing Record 43 of Set 2 | bredasdorp
# Processing Record 44 of Set 2 | srednekolymsk
# Processing Record 45 of Set 2 | souillac
# Processing Record 46 of Set 2 | kloulklubed
# Processing Record 47 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 2 | longyearbyen
# Processing Record 50 of Set 2 | klaksvik
# Processing Record 1 of Set 3 | melilla
# Processing Record 2 of Set 3 | severo-kurilsk
# Processing Record 3 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 3 | grootfontein
# Processing Record 5 of Set 3 | hamilton
# Processing Record 6 of Set 3 | edeia
# Processing Record 7 of Set 3 | nan
# Processing Record 8 of Set 3 | new norfolk
# Processing Record 9 of Set 3 | kruisfontein
# Processing Record 10 of Set 3 | wynyard
# Processing Record 11 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 12 of Set 3 | jamestown
# Processing Record 13 of Set 3 | tabory
# Processing Record 14 of Set 3 | kashi
# Processing Record 15 of Set 3 | nova venecia
# Processing Record 16 of Set 3 | mandalgovi
# Processing Record 17 of Set 3 | horki
# Processing Record 18 of Set 3 | pulaski
# Processing Record 19 of Set 3 | hithadhoo
# Processing Record 20 of Set 3 | trinidad
# Processing Record 21 of Set 3 | bethel
# Processing Record 22 of Set 3 | east london
# Processing Record 23 of Set 3 | puerto escondido
# Processing Record 24 of Set 3 | goodlettsville
# Processing Record 25 of Set 3 | college
# Processing Record 26 of Set 3 | huanren
# Processing Record 27 of Set 3 | kismayo
# Processing Record 28 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 3 | vardo
# Processing Record 30 of Set 3 | jumla
# Processing Record 31 of Set 3 | oranjemund
# Processing Record 32 of Set 3 | avarua
# Processing Record 33 of Set 3 | puerto rondon
# Processing Record 34 of Set 3 | aranos
# Processing Record 35 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 3 | pochutla
# Processing Record 37 of Set 3 | mananjary
# Processing Record 38 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 3 | yulara
# Processing Record 40 of Set 3 | high level
# Processing Record 41 of Set 3 | rio grande
# Processing Record 42 of Set 3 | tiksi
# Processing Record 43 of Set 3 | port elizabeth
# Processing Record 44 of Set 3 | pangnirtung
# Processing Record 45 of Set 3 | luwingu
# Processing Record 46 of Set 3 | hasaki
# Processing Record 47 of Set 3 | kapaa
# Processing Record 48 of Set 3 | atuona
# Processing Record 49 of Set 3 | bambous virieux
# Processing Record 50 of Set 3 | hermanus
# Processing Record 1 of Set 4 | zinder
# Processing Record 2 of Set 4 | borogontsy
# Processing Record 3 of Set 4 | perpignan
# Processing Record 4 of Set 4 | stoyba
# City not found. Skipping...
# Processing Record 5 of Set 4 | tangi
# Processing Record 6 of Set 4 | guiratinga
# Processing Record 7 of Set 4 | maceio
# Processing Record 8 of Set 4 | kieta
# Processing Record 9 of Set 4 | jurm
# Processing Record 10 of Set 4 | kokkola
# Processing Record 11 of Set 4 | carnarvon
# Processing Record 12 of Set 4 | karratha
# Processing Record 13 of Set 4 | kyshtovka
# Processing Record 14 of Set 4 | hegang
# Processing Record 15 of Set 4 | nishihara
# Processing Record 16 of Set 4 | tucuman
# Processing Record 17 of Set 4 | dingle
# Processing Record 18 of Set 4 | fortuna
# Processing Record 19 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 4 | machelen
# Processing Record 21 of Set 4 | ilebo
# Processing Record 22 of Set 4 | okato
# Processing Record 23 of Set 4 | loandjili
# Processing Record 24 of Set 4 | nikolskoye
# Processing Record 25 of Set 4 | mirabela
# Processing Record 26 of Set 4 | gazanjyk
# Processing Record 27 of Set 4 | altamira
# Processing Record 28 of Set 4 | atasu
# Processing Record 29 of Set 4 | san cristobal
# Processing Record 30 of Set 4 | tura
# Processing Record 31 of Set 4 | fort frances
# Processing Record 32 of Set 4 | ampanihy
# Processing Record 33 of Set 4 | san quintin
# Processing Record 34 of Set 4 | provideniya
# Processing Record 35 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 36 of Set 4 | nola
# Processing Record 37 of Set 4 | kahului
# Processing Record 38 of Set 4 | camacupa
# Processing Record 39 of Set 4 | navrongo
# Processing Record 40 of Set 4 | qaqortoq
# Processing Record 41 of Set 4 | kashin
# Processing Record 42 of Set 4 | pisco
# Processing Record 43 of Set 4 | muskegon
# Processing Record 44 of Set 4 | te anau
# Processing Record 45 of Set 4 | port arthur
# Processing Record 46 of Set 4 | aki
# Processing Record 47 of Set 4 | ye
# City not found. Skipping...
# Processing Record 48 of Set 4 | santa isabel
# Processing Record 49 of Set 4 | sao gabriel da cachoeira
# Processing Record 50 of Set 4 | lushunkou
# City not found. Skipping...
# Processing Record 1 of Set 5 | waingapu
# Processing Record 2 of Set 5 | batemans bay
# Processing Record 3 of Set 5 | sabang
# Processing Record 4 of Set 5 | santa rosa
# Processing Record 5 of Set 5 | bilma
# Processing Record 6 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 5 | orneta
# Processing Record 8 of Set 5 | kyritz
# Processing Record 9 of Set 5 | victoria
# Processing Record 10 of Set 5 | samarai
# Processing Record 11 of Set 5 | karasburg
# Processing Record 12 of Set 5 | dukat
# Processing Record 13 of Set 5 | boyabat
# Processing Record 14 of Set 5 | hofn
# Processing Record 15 of Set 5 | moree
# Processing Record 16 of Set 5 | kearney
# Processing Record 17 of Set 5 | mahajanga
# Processing Record 18 of Set 5 | kargala
# Processing Record 19 of Set 5 | yellowknife
# Processing Record 20 of Set 5 | khatanga
# Processing Record 21 of Set 5 | yanam
# Processing Record 22 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 5 | lipin bor
# Processing Record 24 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 25 of Set 5 | komsomolskiy
# Processing Record 26 of Set 5 | worland
# Processing Record 27 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 5 | statesboro
# Processing Record 29 of Set 5 | volax
# Processing Record 30 of Set 5 | tautira
# Processing Record 31 of Set 5 | canavieiras
# Processing Record 32 of Set 5 | praya
# Processing Record 33 of Set 5 | sur
# Processing Record 34 of Set 5 | waddan
# Processing Record 35 of Set 5 | kosa
# Processing Record 36 of Set 5 | pevek
# Processing Record 37 of Set 5 | tapes
# Processing Record 38 of Set 5 | santa cruz
# Processing Record 39 of Set 5 | shelburne
# Processing Record 40 of Set 5 | pecos
# Processing Record 41 of Set 5 | chuy
# Processing Record 42 of Set 5 | nantucket
# Processing Record 43 of Set 5 | ostrovnoy
# Processing Record 44 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 5 | esperance
# Processing Record 46 of Set 5 | miles city
# Processing Record 47 of Set 5 | alexandria
# Processing Record 48 of Set 5 | crestview
# Processing Record 49 of Set 5 | chokurdakh
# Processing Record 50 of Set 5 | meulaboh
# Processing Record 1 of Set 6 | bonavista
# Processing Record 2 of Set 6 | saldanha
# Processing Record 3 of Set 6 | olafsvik
# Processing Record 4 of Set 6 | mandera
# Processing Record 5 of Set 6 | goderich
# Processing Record 6 of Set 6 | sarkand
# Processing Record 7 of Set 6 | antofagasta
# Processing Record 8 of Set 6 | marsabit
# Processing Record 9 of Set 6 | bubaque
# Processing Record 10 of Set 6 | gambela
# Processing Record 11 of Set 6 | hambantota
# Processing Record 12 of Set 6 | lekoni
# Processing Record 13 of Set 6 | lodja
# Processing Record 14 of Set 6 | gazojak
# Processing Record 15 of Set 6 | honningsvag
# Processing Record 16 of Set 6 | kulhudhuffushi
# Processing Record 17 of Set 6 | sept-iles
# Processing Record 18 of Set 6 | selikhino
# Processing Record 19 of Set 6 | roald
# Processing Record 20 of Set 6 | basey
# Processing Record 21 of Set 6 | mar del plata
# Processing Record 22 of Set 6 | saint-augustin
# Processing Record 23 of Set 6 | panjab
# Processing Record 24 of Set 6 | farah
# Processing Record 25 of Set 6 | cordoba
# Processing Record 26 of Set 6 | nanortalik
# Processing Record 27 of Set 6 | oswego
# Processing Record 28 of Set 6 | berezovka
# Processing Record 29 of Set 6 | cerrito
# Processing Record 30 of Set 6 | sanming
# Processing Record 31 of Set 6 | okha
# Processing Record 32 of Set 6 | oktyabrskoye
# Processing Record 33 of Set 6 | pilar
# Processing Record 34 of Set 6 | port augusta
# Processing Record 35 of Set 6 | alofi
# Processing Record 36 of Set 6 | kidal
# Processing Record 37 of Set 6 | ust-tsilma
# Processing Record 38 of Set 6 | upernavik
# Processing Record 39 of Set 6 | kamenka
# Processing Record 40 of Set 6 | lorengau
# Processing Record 41 of Set 6 | acapulco
# Processing Record 42 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 6 | niquelandia
# Processing Record 44 of Set 6 | new waterford
# Processing Record 45 of Set 6 | avera
# Processing Record 46 of Set 6 | flekkefjord
# Processing Record 47 of Set 6 | tasiilaq
# Processing Record 48 of Set 6 | williston
# Processing Record 49 of Set 6 | awjilah
# Processing Record 50 of Set 6 | buin
# Processing Record 1 of Set 7 | arys
# Processing Record 2 of Set 7 | bandarbeyla
# Processing Record 3 of Set 7 | sterlitamak
# Processing Record 4 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 7 | mecca
# Processing Record 6 of Set 7 | chara
# Processing Record 7 of Set 7 | luanda
# Processing Record 8 of Set 7 | marathon
# Processing Record 9 of Set 7 | arlit
# Processing Record 10 of Set 7 | davila
# Processing Record 11 of Set 7 | guantanamo
# Processing Record 12 of Set 7 | saint-francois
# Processing Record 13 of Set 7 | urusha
# Processing Record 14 of Set 7 | grindavik
# Processing Record 15 of Set 7 | codrington
# Processing Record 16 of Set 7 | deir hanna
# Processing Record 17 of Set 7 | denpasar
# Processing Record 18 of Set 7 | saint-joseph
# Processing Record 19 of Set 7 | paamiut
# Processing Record 20 of Set 7 | port macquarie
# Processing Record 21 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 7 | pangkalanbuun
# Processing Record 23 of Set 7 | rawson
# Processing Record 24 of Set 7 | moranbah
# Processing Record 25 of Set 7 | amudat
# Processing Record 26 of Set 7 | otradnoye
# Processing Record 27 of Set 7 | porto novo
# Processing Record 28 of Set 7 | puro
# Processing Record 29 of Set 7 | kawana waters
# City not found. Skipping...
# Processing Record 30 of Set 7 | cockburn town
# Processing Record 31 of Set 7 | oistins
# Processing Record 32 of Set 7 | lagos
# Processing Record 33 of Set 7 | buala
# Processing Record 34 of Set 7 | sakakah
# Processing Record 35 of Set 7 | hami
# Processing Record 36 of Set 7 | karatau
# Processing Record 37 of Set 7 | qianan
# Processing Record 38 of Set 7 | vadso
# Processing Record 39 of Set 7 | curaca
# Processing Record 40 of Set 7 | flagstaff
# Processing Record 41 of Set 7 | baculin
# Processing Record 42 of Set 7 | caravelas
# Processing Record 43 of Set 7 | sibiti
# Processing Record 44 of Set 7 | katsuura
# Processing Record 45 of Set 7 | puerto carreno
# Processing Record 46 of Set 7 | kuna
# Processing Record 47 of Set 7 | karakose
# City not found. Skipping...
# Processing Record 48 of Set 7 | laguna
# Processing Record 49 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 50 of Set 7 | gamba
# Processing Record 1 of Set 8 | dikson
# Processing Record 2 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 8 | gangtok
# Processing Record 4 of Set 8 | arman
# Processing Record 5 of Set 8 | spornoye
# Processing Record 6 of Set 8 | itarema
# Processing Record 7 of Set 8 | tessalit
# Processing Record 8 of Set 8 | gravdal
# Processing Record 9 of Set 8 | bathsheba
# Processing Record 10 of Set 8 | portland
# Processing Record 11 of Set 8 | neuquen
# Processing Record 12 of Set 8 | huarmey
# Processing Record 13 of Set 8 | port-gentil
# Processing Record 14 of Set 8 | cayenne
# Processing Record 15 of Set 8 | cockburn harbour
# City not found. Skipping...
# Processing Record 16 of Set 8 | nemuro
# Processing Record 17 of Set 8 | broome
# Processing Record 18 of Set 8 | general pico
# Processing Record 19 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 20 of Set 8 | belmonte
# Processing Record 21 of Set 8 | wattegama
# Processing Record 22 of Set 8 | burns lake
# Processing Record 23 of Set 8 | grafton
# Processing Record 24 of Set 8 | pingliang
# Processing Record 25 of Set 8 | zharkent
# Processing Record 26 of Set 8 | eureka
# Processing Record 27 of Set 8 | krasnyy chikoy
# Processing Record 28 of Set 8 | camacha
# Processing Record 29 of Set 8 | kalabo
# Processing Record 30 of Set 8 | green river
# Processing Record 31 of Set 8 | khandyga
# Processing Record 32 of Set 8 | lucapa
# Processing Record 33 of Set 8 | flin flon
# Processing Record 34 of Set 8 | halifax
# Processing Record 35 of Set 8 | ilulissat
# Processing Record 36 of Set 8 | basco
# Processing Record 37 of Set 8 | meru
# Processing Record 38 of Set 8 | baykit
# Processing Record 39 of Set 8 | fare
# Processing Record 40 of Set 8 | burnie
# Processing Record 41 of Set 8 | albertville
# Processing Record 42 of Set 8 | aklavik
# Processing Record 43 of Set 8 | durango
# Processing Record 44 of Set 8 | mentok
# City not found. Skipping...
# Processing Record 45 of Set 8 | ketchikan
# Processing Record 46 of Set 8 | dakar
# Processing Record 47 of Set 8 | cabo san lucas
# Processing Record 48 of Set 8 | potgietersrus
# City not found. Skipping...
# Processing Record 49 of Set 8 | nanakuli
# Processing Record 50 of Set 8 | port moresby
# Processing Record 1 of Set 9 | ahipara
# Processing Record 2 of Set 9 | wasilla
# Processing Record 3 of Set 9 | nyurba
# Processing Record 4 of Set 9 | fomboni
# Processing Record 5 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 9 | kendari
# Processing Record 7 of Set 9 | burica
# City not found. Skipping...
# Processing Record 8 of Set 9 | crotone
# Processing Record 9 of Set 9 | palestine
# Processing Record 10 of Set 9 | matagami
# Processing Record 11 of Set 9 | carmen
# Processing Record 12 of Set 9 | cap malheureux
# Processing Record 13 of Set 9 | iquique
# Processing Record 14 of Set 9 | uvinza
# Processing Record 15 of Set 9 | nizwa
# Processing Record 16 of Set 9 | illapel
# Processing Record 17 of Set 9 | la carolina
# Processing Record 18 of Set 9 | nome
# Processing Record 19 of Set 9 | nago
# Processing Record 20 of Set 9 | bondoukou
# Processing Record 21 of Set 9 | taburi
# City not found. Skipping...
# Processing Record 22 of Set 9 | half moon bay
# Processing Record 23 of Set 9 | abu kamal
# Processing Record 24 of Set 9 | george town
# Processing Record 25 of Set 9 | fort nelson
# Processing Record 26 of Set 9 | drumnadrochit
# Processing Record 27 of Set 9 | kungurtug
# Processing Record 28 of Set 9 | vaitape
# Processing Record 29 of Set 9 | ust-kan
# Processing Record 30 of Set 9 | aksu
# Processing Record 31 of Set 9 | kiama
# Processing Record 32 of Set 9 | thinadhoo
# Processing Record 33 of Set 9 | ust-maya
# Processing Record 34 of Set 9 | aran
# Processing Record 35 of Set 9 | castro
# Processing Record 36 of Set 9 | sweetwater
# Processing Record 37 of Set 9 | makakilo city
# Processing Record 38 of Set 9 | alta floresta
# Processing Record 39 of Set 9 | teluknaga
# Processing Record 40 of Set 9 | mount gambier
# Processing Record 41 of Set 9 | okhotsk
# Processing Record 42 of Set 9 | zhigansk
# Processing Record 43 of Set 9 | sola
# Processing Record 44 of Set 9 | uniao da victoria
# City not found. Skipping...
# Processing Record 45 of Set 9 | kodinsk
# Processing Record 46 of Set 9 | pocone
# Processing Record 47 of Set 9 | sampit
# Processing Record 48 of Set 9 | norton
# Processing Record 49 of Set 9 | bulgan
# Processing Record 50 of Set 9 | birao
# Processing Record 1 of Set 10 | san patricio
# Processing Record 2 of Set 10 | hoogeveen
# Processing Record 3 of Set 10 | guerrero negro
# Processing Record 4 of Set 10 | sibu
# Processing Record 5 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 10 | sioux lookout
# Processing Record 7 of Set 10 | pedernales
# Processing Record 8 of Set 10 | creel
# Processing Record 9 of Set 10 | darhan
# Processing Record 10 of Set 10 | marsa matruh
# Processing Record 11 of Set 10 | kysyl-syr
# Processing Record 12 of Set 10 | melfi
# Processing Record 13 of Set 10 | sao filipe
# Processing Record 14 of Set 10 | ambovombe
# Processing Record 15 of Set 10 | gualaceo
# Processing Record 16 of Set 10 | nosy varika
# Processing Record 17 of Set 10 | tsumeb
# Processing Record 18 of Set 10 | daru
# Processing Record 19 of Set 10 | miri
# Processing Record 20 of Set 10 | keti bandar
# Processing Record 21 of Set 10 | le mars
# Processing Record 22 of Set 10 | iqaluit
# Processing Record 23 of Set 10 | high rock
# Processing Record 24 of Set 10 | port-cartier
# Processing Record 25 of Set 10 | penzance
# Processing Record 26 of Set 10 | along
# Processing Record 27 of Set 10 | asayita
# City not found. Skipping...
# Processing Record 28 of Set 10 | san ignacio
# Processing Record 29 of Set 10 | padang
# Processing Record 30 of Set 10 | lompoc
# Processing Record 31 of Set 10 | kabalo
# Processing Record 32 of Set 10 | romitan
# Processing Record 33 of Set 10 | tezu
# Processing Record 34 of Set 10 | asopos
# Processing Record 35 of Set 10 | verkhnyaya sinyachikha
# Processing Record 36 of Set 10 | weligama
# Processing Record 37 of Set 10 | bin qirdan
# Processing Record 38 of Set 10 | omsukchan
# Processing Record 39 of Set 10 | sinjar
# Processing Record 40 of Set 10 | barra patuca
# Processing Record 41 of Set 10 | namibe
# Processing Record 42 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 10 | barcelos
# Processing Record 44 of Set 10 | port hedland
# Processing Record 45 of Set 10 | alice springs
# Processing Record 46 of Set 10 | teguise
# Processing Record 47 of Set 10 | champerico
# Processing Record 48 of Set 10 | novaya bryan
# Processing Record 49 of Set 10 | tigzirt
# Processing Record 50 of Set 10 | vredendal
# Processing Record 1 of Set 11 | aksarka
# Processing Record 2 of Set 11 | slave lake
# Processing Record 3 of Set 11 | lohardaga
# Processing Record 4 of Set 11 | xixiang
# Processing Record 5 of Set 11 | sofiysk
# City not found. Skipping...
# Processing Record 6 of Set 11 | erenhot
# Processing Record 7 of Set 11 | valparaiso
# Processing Record 8 of Set 11 | cruzilia
# Processing Record 9 of Set 11 | axim
# Processing Record 10 of Set 11 | ponta delgada
# Processing Record 11 of Set 11 | kudahuvadhoo
# Processing Record 12 of Set 11 | hervey bay
# Processing Record 13 of Set 11 | tarime
# Processing Record 14 of Set 11 | phek
# Processing Record 15 of Set 11 | tilichiki
# Processing Record 16 of Set 11 | acuna
# City not found. Skipping...
# Processing Record 17 of Set 11 | buraydah
# Processing Record 18 of Set 11 | gunjur
# Processing Record 19 of Set 11 | beloha
# Processing Record 20 of Set 11 | eston
# Processing Record 21 of Set 11 | labuhan
# Processing Record 22 of Set 11 | mahebourg
# Processing Record 23 of Set 11 | vila franca do campo
# Processing Record 24 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 25 of Set 11 | faanui
# Processing Record 26 of Set 11 | coquimbo
# Processing Record 27 of Set 11 | figeac
# Processing Record 28 of Set 11 | mullaitivu
# City not found. Skipping...
# Processing Record 29 of Set 11 | torbay
# Processing Record 30 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 31 of Set 11 | shushary
# Processing Record 32 of Set 11 | sungaipenuh
# Processing Record 33 of Set 11 | cidreira
# Processing Record 34 of Set 11 | bellavista
# Processing Record 35 of Set 11 | yar-sale
# Processing Record 36 of Set 11 | nelson bay
# Processing Record 37 of Set 11 | swan hill
# Processing Record 38 of Set 11 | pacific grove
# Processing Record 39 of Set 11 | swellendam
# Processing Record 40 of Set 11 | sangar
# Processing Record 41 of Set 11 | kavieng
# Processing Record 42 of Set 11 | taltal
# Processing Record 43 of Set 11 | la ronge
# Processing Record 44 of Set 11 | paita
# Processing Record 45 of Set 11 | charlestown
# Processing Record 46 of Set 11 | yushu
# Processing Record 47 of Set 11 | faya
# Processing Record 48 of Set 11 | ibotirama
# Processing Record 49 of Set 11 | talnakh
# Processing Record 50 of Set 11 | ibra
# Processing Record 1 of Set 12 | lithakia
# Processing Record 2 of Set 12 | bahia honda
# Processing Record 3 of Set 12 | caibarien
# Processing Record 4 of Set 12 | magnolia
# Processing Record 5 of Set 12 | palmer
# Processing Record 6 of Set 12 | cururupu
# Processing Record 7 of Set 12 | kerman
# Processing Record 8 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 12 | bordighera
# Processing Record 10 of Set 12 | margate
# Processing Record 11 of Set 12 | tirumullaivasal
# Processing Record 12 of Set 12 | boguchany
# Processing Record 13 of Set 12 | gordeyevka
# Processing Record 14 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 12 | cam ranh
# Processing Record 16 of Set 12 | weatherford
# Processing Record 17 of Set 12 | great yarmouth
# Processing Record 18 of Set 12 | scottsbluff
# Processing Record 19 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 20 of Set 12 | norman wells
# Processing Record 21 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 12 | naze
# Processing Record 23 of Set 12 | kaitangata
# Processing Record 24 of Set 12 | quatre cocos
# Processing Record 25 of Set 12 | ometepec
# Processing Record 26 of Set 12 | santa luzia
# Processing Record 27 of Set 12 | pokhara
# Processing Record 28 of Set 12 | riyadh
# Processing Record 29 of Set 12 | merauke
# Processing Record 30 of Set 12 | jacareacanga
# Processing Record 31 of Set 12 | olinda
# Processing Record 32 of Set 12 | anloga
# Processing Record 33 of Set 12 | yatou
# Processing Record 34 of Set 12 | toropets
# Processing Record 35 of Set 12 | necochea
# Processing Record 36 of Set 12 | vostok
# Processing Record 37 of Set 12 | isla mujeres
# Processing Record 38 of Set 12 | majalengka
# Processing Record 39 of Set 12 | berlevag
# Processing Record 40 of Set 12 | kralendijk
# Processing Record 41 of Set 12 | pandan
# Processing Record 42 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 43 of Set 12 | lander
# Processing Record 44 of Set 12 | plettenberg bay
# Processing Record 45 of Set 12 | tuatapere
# Processing Record 46 of Set 12 | elk
# Processing Record 47 of Set 12 | torzhok
# Processing Record 48 of Set 12 | vila
# Processing Record 49 of Set 12 | beaverlodge
# Processing Record 50 of Set 12 | velikiy ustyug
# Processing Record 1 of Set 13 | lincoln
# Processing Record 2 of Set 13 | porto torres
# Processing Record 3 of Set 13 | taoudenni
# Processing Record 4 of Set 13 | madison
# Processing Record 5 of Set 13 | ozinki
# Processing Record 6 of Set 13 | vao
# Processing Record 7 of Set 13 | praia
# Processing Record 8 of Set 13 | hluti
# Processing Record 9 of Set 13 | russell
# Processing Record 10 of Set 13 | kifri
# Processing Record 11 of Set 13 | coihaique
# Processing Record 12 of Set 13 | matamoros
# Processing Record 13 of Set 13 | hirara
# Processing Record 14 of Set 13 | syracuse
# Processing Record 15 of Set 13 | usevya
# Processing Record 16 of Set 13 | nouadhibou
# Processing Record 17 of Set 13 | port hardy
# Processing Record 18 of Set 13 | vytegra
# Processing Record 19 of Set 13 | eslamshahr
# Processing Record 20 of Set 13 | chernukha
# Processing Record 21 of Set 13 | clarence town
# Processing Record 22 of Set 13 | westport
# Processing Record 23 of Set 13 | ginda
# Processing Record 24 of Set 13 | borovskiy
# Processing Record 25 of Set 13 | papenburg
# Processing Record 26 of Set 13 | biak
# Processing Record 27 of Set 13 | doka
# Processing Record 28 of Set 13 | ifakara
# Processing Record 29 of Set 13 | parainen
# Processing Record 30 of Set 13 | achutupo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 580

# %%
city_data
# Out:
# [{'City': 'Cape Town',
#   'Lat': -33.93,
#   'Lng': 18.42,
#   'Max Temp': 60.01,
#   'Humidity': 47,
#   'Cloudiness': 90,
#   'Wind Speed': 9.17,
#   'Country': 'ZA',
#   'Date': '2020-07-08 22:41:10'},
#  {'City': 'Kavaratti',
#   'Lat': 10.57,
#   'Lng': 72.64,
#   'Max Temp': 83.71,
#   'Humidity': 73,
#   'Cloudiness': 99,
#   'Wind Speed': 17.43,
#   'Country': 'IN',
#   'Date': '2020-07-08 22:45:21'},
#  {'City': 'Georgetown',
#   'Lat': 5.41,
#   'Lng': 100.34,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 1.12,
#   'Country': 'MY',
#   'Date': '2020-07-08 22:45:21'},
#  {'City': 'Nagua',
#   'Lat': 19.38,
#   'Lng': -69.85,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 7.23,
#   'Country': 'DO',
#   'Date': '2020-07-08 22:45:21'},
#  {'City': 'Turbat',
#   'Lat': 26,
#   'Lng': 63.04,
#   'Max Temp': 85.55,
#   'Humidity': 68,
#   'Cloudiness': 98,
#   'Wind Speed': 9.06,
#   'Country': 'PK',
#   'Date': '2020-07-08 22:45:21'},
#  {'City': 'La Rioja',
#   'Lat': 42.25,
#   'Lng': -2.5,
#   'Max Temp': 75.2,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 6.93,
#   'Country': 'ES',
#   'Date': '2020-07-08 22:43:39'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.33,
#   'Max Temp': 48.18,
#   'Humidity': 80,
#   'Cloudiness': 81,
#   'Wind Speed': 13.98,
#   'Country': 'NZ',
#   'Date': '2020-07-08 22:45:10'},
#  {'City': 'Clyde River',
#   'Lat': 70.47,
#   'Lng': -68.59,
#   'Max Temp': 37.4,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Country': 'CA',
#   'Date': '2020-07-08 22:45:13'},
#  {'City': 'Leningradskiy',
#   'Lat': 69.38,
#   'Lng': 178.42,
#   'Max Temp': 48.87,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 10.87,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:41:07'},
#  {'City': 'Lupiro',
#   'Lat': -8.38,
#   'Lng': 36.67,
#   'Max Temp': 73.56,
#   'Humidity': 66,
#   'Cloudiness': 94,
#   'Wind Speed': 4.94,
#   'Country': 'TZ',
#   'Date': '2020-07-08 22:45:21'},
#  {'City': 'Hilo',
#   'Lat': 19.73,
#   'Lng': -155.09,
#   'Max Temp': 82.4,
#   'Humidity': 65,
#   'Cloudiness': 90,
#   'Wind Speed': 13.87,
#   'Country': 'US',
#   'Date': '2020-07-08 22:45:21'},
#  {'City': 'Rikitea',
#   'Lat': -23.12,
#   'Lng': -134.97,
#   'Max Temp': 67.57,
#   'Humidity': 63,
#   'Cloudiness': 23,
#   'Wind Speed': 18.07,
#   'Country': 'PF',
#   'Date': '2020-07-08 22:45:03'},
#  {'City': 'Pittsfield',
#   'Lat': 42.45,
#   'Lng': -73.25,
#   'Max Temp': 73.99,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Country': 'US',
#   'Date': '2020-07-08 22:44:08'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Country': 'TO',
#   'Date': '2020-07-08 22:45:21'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.45,
#   'Lng': -133.04,
#   'Max Temp': 37.4,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Country': 'CA',
#   'Date': '2020-07-08 22:45:22'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.92,
#   'Max Temp': 32,
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Country': 'CL',
#   'Date': '2020-07-08 22:45:22'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.97,
#   'Lng': -42.03,
#   'Max Temp': 73.45,
#   'Humidity': 75,
#   'Cloudiness': 4,
#   'Wind Speed': 24.32,
#   'Country': 'BR',
#   'Date': '2020-07-08 22:41:16'},
#  {'City': 'Agadez',
#   'Lat': 19.75,
#   'Lng': 10.25,
#   'Max Temp': 88.93,
#   'Humidity': 27,
#   'Cloudiness': 46,
#   'Wind Speed': 8.68,
#   'Country': 'NE',
#   'Date': '2020-07-08 22:45:22'},
#  {'City': 'Albany',
#   'Lat': 42.6,
#   'Lng': -73.97,
#   'Max Temp': 77,
#   'Humidity': 80,
#   'Cloudiness': 64,
#   'Wind Speed': 3.53,
#   'Country': 'US',
#   'Date': '2020-07-08 22:45:22'},
#  {'City': 'Matara',
#   'Lat': 5.95,
#   'Lng': 80.54,
#   'Max Temp': 79.34,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 10.54,
#   'Country': 'LK',
#   'Date': '2020-07-08 22:45:22'},
#  {'City': 'Lebu',
#   'Lat': -37.62,
#   'Lng': -73.65,
#   'Max Temp': 48.79,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 8.32,
#   'Country': 'CL',
#   'Date': '2020-07-08 22:43:04'},
#  {'City': 'Marsh Harbour',
#   'Lat': 26.54,
#   'Lng': -77.06,
#   'Max Temp': 85.41,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Country': 'BS',
#   'Date': '2020-07-08 22:45:22'},
#  {'City': 'Butaritari',
#   'Lat': 3.07,
#   'Lng': 172.79,
#   'Max Temp': 83.48,
#   'Humidity': 77,
#   'Cloudiness': 5,
#   'Wind Speed': 16.71,
#   'Country': 'KI',
#   'Date': '2020-07-08 22:45:22'},
#  {'City': 'Killybegs',
#   'Lat': 54.63,
#   'Lng': -8.45,
#   'Max Temp': 52,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Country': 'IE',
#   'Date': '2020-07-08 22:45:22'},
#  {'City': 'Adrar',
#   'Lat': 20.5,
#   'Lng': -10.07,
#   'Max Temp': 98.35,
#   'Humidity': 9,
#   'Cloudiness': 28,
#   'Wind Speed': 14.74,
#   'Country': 'MR',
#   'Date': '2020-07-08 22:41:58'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.67,
#   'Lng': -17.1,
#   'Max Temp': 69.8,
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 10.29,
#   'Country': 'PT',
#   'Date': '2020-07-08 22:43:28'},
#  {'City': 'Narsaq',
#   'Lat': 60.92,
#   'Lng': -46.05,
#   'Max Temp': 55.4,
#   'Humidity': 54,
#   'Cloudiness': 93,
#   'Wind Speed': 3.36,
#   'Country': 'GL',
#   'Date': '2020-07-08 22:45:22'},
#  {'City': 'Cadillac',
#   'Lat': 44.25,
#   'Lng': -85.4,
#   'Max Temp': 87.8,
#   'Humidity': 45,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Country': 'US',
#   'Date': '2020-07-08 22:45:22'},
#  {'City': 'Taguatinga',
#   'Lat': -12.39,
#   'Lng': -46.57,
#   'Max Temp': 74.44,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 4.29,
#   'Country': 'BR',
#   'Date': '2020-07-08 22:45:22'},
#  {'City': 'Tabuk',
#   'Lat': 17.42,
#   'Lng': 121.44,
#   'Max Temp': 78.48,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 0.6,
#   'Country': 'PH',
#   'Date': '2020-07-08 22:45:22'},
#  {'City': 'Hobart',
#   'Lat': -42.88,
#   'Lng': 147.33,
#   'Max Temp': 39,
#   'Humidity': 86,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Date': '2020-07-08 22:43:59'},
#  {'City': 'Geraldton',
#   'Lat': -28.77,
#   'Lng': 114.6,
#   'Max Temp': 46.4,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Country': 'AU',
#   'Date': '2020-07-08 22:45:22'},
#  {'City': 'Soyo',
#   'Lat': -6.13,
#   'Lng': 12.37,
#   'Max Temp': 73.42,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 6.85,
#   'Country': 'AO',
#   'Date': '2020-07-08 22:42:03'},
#  {'City': 'Mataura',
#   'Lat': -46.19,
#   'Lng': 168.86,
#   'Max Temp': 41.88,
#   'Humidity': 92,
#   'Cloudiness': 87,
#   'Wind Speed': 4.59,
#   'Country': 'NZ',
#   'Date': '2020-07-08 22:45:10'},
#  {'City': 'Touros',
#   'Lat': -5.2,
#   'Lng': -35.46,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 3.36,
#   'Country': 'BR',
#   'Date': '2020-07-08 22:45:23'},
#  {'City': 'Namatanai',
#   'Lat': -3.67,
#   'Lng': 152.43,
#   'Max Temp': 83.75,
#   'Humidity': 68,
#   'Cloudiness': 60,
#   'Wind Speed': 4.27,
#   'Country': 'PG',
#   'Date': '2020-07-08 22:45:23'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 41,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 9.17,
#   'Country': 'AR',
#   'Date': '2020-07-08 22:42:32'},
#  {'City': 'Port Alfred',
#   'Lat': -33.59,
#   'Lng': 26.89,
#   'Max Temp': 71.01,
#   'Humidity': 44,
#   'Cloudiness': 3,
#   'Wind Speed': 5.01,
#   'Country': 'ZA',
#   'Date': '2020-07-08 22:45:23'},
#  {'City': 'Luderitz',
#   'Lat': -26.65,
#   'Lng': 15.16,
#   'Max Temp': 59,
#   'Humidity': 58,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7,
#   'Country': 'NA',
#   'Date': '2020-07-08 22:45:23'},
#  {'City': 'Pacifica',
#   'Lat': 37.61,
#   'Lng': -122.49,
#   'Max Temp': 68,
#   'Humidity': 82,
#   'Cloudiness': 1,
#   'Wind Speed': 11.41,
#   'Country': 'US',
#   'Date': '2020-07-08 22:45:23'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.52,
#   'Lng': -28.7,
#   'Max Temp': 69.8,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'PT',
#   'Date': '2020-07-08 22:45:23'},
#  {'City': 'Khabary',
#   'Lat': 53.63,
#   'Lng': 79.53,
#   'Max Temp': 62.08,
#   'Humidity': 87,
#   'Cloudiness': 7,
#   'Wind Speed': 6.8,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:45:23'},
#  {'City': 'Porto Seguro',
#   'Lat': -16.45,
#   'Lng': -39.06,
#   'Max Temp': 73.4,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7,
#   'Country': 'BR',
#   'Date': '2020-07-08 22:40:26'},
#  {'City': 'Sitka',
#   'Lat': 57.05,
#   'Lng': -135.33,
#   'Max Temp': 57.2,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Country': 'US',
#   'Date': '2020-07-08 22:45:23'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.33,
#   'Max Temp': 41,
#   'Humidity': 99,
#   'Cloudiness': 94,
#   'Wind Speed': 7.43,
#   'Country': 'AU',
#   'Date': '2020-07-08 22:45:23'},
#  {'City': 'Thompson',
#   'Lat': 55.74,
#   'Lng': -97.86,
#   'Max Temp': 78.8,
#   'Humidity': 41,
#   'Cloudiness': 90,
#   'Wind Speed': 2.24,
#   'Country': 'CA',
#   'Date': '2020-07-08 22:45:13'},
#  {'City': 'Meadela',
#   'Lat': 41.71,
#   'Lng': -8.8,
#   'Max Temp': 68,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Country': 'PT',
#   'Date': '2020-07-08 22:45:23'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.74,
#   'Lng': -90.35,
#   'Max Temp': 69.01,
#   'Humidity': 92,
#   'Cloudiness': 80,
#   'Wind Speed': 1.99,
#   'Country': 'EC',
#   'Date': '2020-07-08 22:45:23'},
#  {'City': 'Amapa',
#   'Lat': 1,
#   'Lng': -52,
#   'Max Temp': 76.55,
#   'Humidity': 83,
#   'Cloudiness': 86,
#   'Wind Speed': 3,
#   'Country': 'BR',
#   'Date': '2020-07-08 22:45:23'},
#  {'City': 'Kamiiso',
#   'Lat': 41.82,
#   'Lng': 140.65,
#   'Max Temp': 66.2,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'JP',
#   'Date': '2020-07-08 22:45:23'},
#  {'City': 'Kamina',
#   'Lat': -8.74,
#   'Lng': 24.99,
#   'Max Temp': 63.14,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 3.56,
#   'Country': 'CD',
#   'Date': '2020-07-08 22:45:24'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 69.66,
#   'Humidity': 49,
#   'Cloudiness': 81,
#   'Wind Speed': 12.15,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:43:45'},
#  {'City': 'Nisia Floresta',
#   'Lat': -6.09,
#   'Lng': -35.21,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 3.36,
#   'Country': 'BR',
#   'Date': '2020-07-08 22:45:24'},
#  {'City': 'Mount Darwin',
#   'Lat': -16.77,
#   'Lng': 31.58,
#   'Max Temp': 54.19,
#   'Humidity': 78,
#   'Cloudiness': 7,
#   'Wind Speed': 4.85,
#   'Country': 'ZW',
#   'Date': '2020-07-08 22:45:24'},
#  {'City': 'Shenzhen',
#   'Lat': 22.55,
#   'Lng': 114.07,
#   'Max Temp': 86,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Country': 'CN',
#   'Date': '2020-07-08 22:41:59'},
#  {'City': 'Ilhabela',
#   'Lat': -23.78,
#   'Lng': -45.36,
#   'Max Temp': 73.26,
#   'Humidity': 65,
#   'Cloudiness': 58,
#   'Wind Speed': 4.5,
#   'Country': 'BR',
#   'Date': '2020-07-08 22:45:24'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.41,
#   'Max Temp': 64.4,
#   'Humidity': 55,
#   'Cloudiness': 1,
#   'Wind Speed': 11.41,
#   'Country': 'US',
#   'Date': '2020-07-08 22:45:24'},
#  {'City': 'Itarsi',
#   'Lat': 22.62,
#   'Lng': 77.75,
#   'Max Temp': 80.35,
#   'Humidity': 80,
#   'Cloudiness': 74,
#   'Wind Speed': 6.53,
#   'Country': 'IN',
#   'Date': '2020-07-08 22:45:24'},
#  {'City': 'Ancud',
#   'Lat': -41.87,
#   'Lng': -73.82,
#   'Max Temp': 44.01,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Country': 'CL',
#   'Date': '2020-07-08 22:45:24'},
#  {'City': 'Airai',
#   'Lat': -8.93,
#   'Lng': 125.41,
#   'Max Temp': 57.4,
#   'Humidity': 99,
#   'Cloudiness': 32,
#   'Wind Speed': 3.87,
#   'Country': 'TL',
#   'Date': '2020-07-08 22:44:08'},
#  {'City': 'Saint George',
#   'Lat': 37.1,
#   'Lng': -113.58,
#   'Max Temp': 102,
#   'Humidity': 5,
#   'Cloudiness': 1,
#   'Wind Speed': 10.29,
#   'Country': 'US',
#   'Date': '2020-07-08 22:43:49'},
#  {'City': 'Subiaco',
#   'Lat': 41.93,
#   'Lng': 13.09,
#   'Max Temp': 72,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Country': 'IT',
#   'Date': '2020-07-08 22:45:25'},
#  {'City': 'Barrow',
#   'Lat': 71.29,
#   'Lng': -156.79,
#   'Max Temp': 46.4,
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind Speed': 16.11,
#   'Country': 'US',
#   'Date': '2020-07-08 22:43:55'},
#  {'City': 'Vila Velha',
#   'Lat': -20.33,
#   'Lng': -40.29,
#   'Max Temp': 73.4,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'BR',
#   'Date': '2020-07-08 22:42:47'},
#  {'City': 'Lagoa',
#   'Lat': 39.05,
#   'Lng': -27.98,
#   'Max Temp': 68.56,
#   'Humidity': 82,
#   'Cloudiness': 97,
#   'Wind Speed': 8.37,
#   'Country': 'PT',
#   'Date': '2020-07-08 22:45:25'},
#  {'City': 'Henties Bay',
#   'Lat': -22.12,
#   'Lng': 14.28,
#   'Max Temp': 57.74,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 4.85,
#   'Country': 'NA',
#   'Date': '2020-07-08 22:45:25'},
#  {'City': 'Zacualpan',
#   'Lat': 21.25,
#   'Lng': -105.17,
#   'Max Temp': 71.6,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 6.15,
#   'Country': 'MX',
#   'Date': '2020-07-08 22:45:26'},
#  {'City': 'Los Llanos De Aridane',
#   'Lat': 28.66,
#   'Lng': -17.92,
#   'Max Temp': 84,
#   'Humidity': 88,
#   'Cloudiness': 2,
#   'Wind Speed': 16.11,
#   'Country': 'ES',
#   'Date': '2020-07-08 22:45:26'},
#  {'City': 'Teacapan',
#   'Lat': 22.55,
#   'Lng': -105.75,
#   'Max Temp': 87.55,
#   'Humidity': 64,
#   'Cloudiness': 92,
#   'Wind Speed': 11.32,
#   'Country': 'MX',
#   'Date': '2020-07-08 22:45:26'},
#  {'City': 'Port Blair',
#   'Lat': 11.67,
#   'Lng': 92.75,
#   'Max Temp': 80.17,
#   'Humidity': 77,
#   'Cloudiness': 94,
#   'Wind Speed': 2.42,
#   'Country': 'IN',
#   'Date': '2020-07-08 22:45:26'},
#  {'City': 'Muros',
#   'Lat': 42.78,
#   'Lng': -9.06,
#   'Max Temp': 66,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 5.01,
#   'Country': 'ES',
#   'Date': '2020-07-08 22:44:55'},
#  {'City': 'Ribeira Brava',
#   'Lat': 32.65,
#   'Lng': -17.07,
#   'Max Temp': 69.8,
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 10.29,
#   'Country': 'PT',
#   'Date': '2020-07-08 22:45:26'},
#  {'City': 'Rafraf',
#   'Lat': 37.19,
#   'Lng': 10.18,
#   'Max Temp': 73.4,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 3.36,
#   'Country': 'TN',
#   'Date': '2020-07-08 22:45:27'},
#  {'City': 'Ullapool',
#   'Lat': 57.9,
#   'Lng': -5.16,
#   'Max Temp': 50,
#   'Humidity': 80,
#   'Cloudiness': 15,
#   'Wind Speed': 1.01,
#   'Country': 'GB',
#   'Date': '2020-07-08 22:45:27'},
#  {'City': 'Poum',
#   'Lat': -20.23,
#   'Lng': 164.02,
#   'Max Temp': 70.3,
#   'Humidity': 67,
#   'Cloudiness': 9,
#   'Wind Speed': 11.01,
#   'Country': 'NC',
#   'Date': '2020-07-08 22:45:27'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8,
#   'Lng': 102.27,
#   'Max Temp': 73.87,
#   'Humidity': 88,
#   'Cloudiness': 79,
#   'Wind Speed': 4.25,
#   'Country': 'ID',
#   'Date': '2020-07-08 22:45:27'},
#  {'City': 'Lavrentiya',
#   'Lat': 65.58,
#   'Lng': -171,
#   'Max Temp': 48.51,
#   'Humidity': 80,
#   'Cloudiness': 37,
#   'Wind Speed': 5.41,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:44:10'},
#  {'City': 'Punta Alta',
#   'Lat': -38.88,
#   'Lng': -62.07,
#   'Max Temp': 44.87,
#   'Humidity': 76,
#   'Cloudiness': 50,
#   'Wind Speed': 19.6,
#   'Country': 'AR',
#   'Date': '2020-07-08 22:45:27'},
#  {'City': 'Batagay',
#   'Lat': 67.63,
#   'Lng': 134.63,
#   'Max Temp': 55.22,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 2.55,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:45:03'},
#  {'City': 'Xining',
#   'Lat': 36.62,
#   'Lng': 101.77,
#   'Max Temp': 57.36,
#   'Humidity': 74,
#   'Cloudiness': 90,
#   'Wind Speed': 3.53,
#   'Country': 'CN',
#   'Date': '2020-07-08 22:45:28'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.48,
#   'Lng': -69.36,
#   'Max Temp': 47.55,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 3.33,
#   'Country': 'GL',
#   'Date': '2020-07-08 22:45:28'},
#  {'City': 'Saskylakh',
#   'Lat': 71.92,
#   'Lng': 114.08,
#   'Max Temp': 58.69,
#   'Humidity': 63,
#   'Cloudiness': 26,
#   'Wind Speed': 10.65,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:45:17'},
#  {'City': 'Krasnoarmeysk',
#   'Lat': 51.02,
#   'Lng': 45.7,
#   'Max Temp': 75.22,
#   'Humidity': 53,
#   'Cloudiness': 26,
#   'Wind Speed': 9.95,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:45:28'},
#  {'City': 'Hovd',
#   'Lat': 48.01,
#   'Lng': 91.64,
#   'Max Temp': 56.68,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 5.5,
#   'Country': 'MN',
#   'Date': '2020-07-08 22:45:28'},
#  {'City': 'Magadan',
#   'Lat': 59.57,
#   'Lng': 150.8,
#   'Max Temp': 50.59,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 8.52,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:45:29'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.36,
#   'Lng': 55.77,
#   'Max Temp': 68,
#   'Humidity': 68,
#   'Cloudiness': 59,
#   'Wind Speed': 11.41,
#   'Country': 'RE',
#   'Date': '2020-07-08 22:45:29'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.53,
#   'Lng': 20.04,
#   'Max Temp': 48.2,
#   'Humidity': 76,
#   'Cloudiness': 99,
#   'Wind Speed': 8.05,
#   'Country': 'ZA',
#   'Date': '2020-07-08 22:45:29'},
#  {'City': 'Srednekolymsk',
#   'Lat': 67.45,
#   'Lng': 153.68,
#   'Max Temp': 58.01,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 2.66,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:45:29'},
#  {'City': 'Souillac',
#   'Lat': -20.52,
#   'Lng': 57.52,
#   'Max Temp': 69.8,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Country': 'MU',
#   'Date': '2020-07-08 22:45:29'},
#  {'City': 'Kloulklubed',
#   'Lat': 7.04,
#   'Lng': 134.26,
#   'Max Temp': 78.8,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 7.74,
#   'Country': 'PW',
#   'Date': '2020-07-08 22:45:29'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.22,
#   'Lng': 15.64,
#   'Max Temp': 44.6,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 3.36,
#   'Country': 'SJ',
#   'Date': '2020-07-08 22:43:13'},
#  {'City': 'Klaksvik',
#   'Lat': 62.23,
#   'Lng': -6.59,
#   'Max Temp': 50,
#   'Humidity': 87,
#   'Cloudiness': 69,
#   'Wind Speed': 4.7,
#   'Country': 'FO',
#   'Date': '2020-07-08 22:45:30'},
#  {'City': 'Melilla',
#   'Lat': 35.29,
#   'Lng': -2.94,
#   'Max Temp': 78.8,
#   'Humidity': 69,
#   'Cloudiness': 80,
#   'Wind Speed': 9.17,
#   'Country': 'ES',
#   'Date': '2020-07-08 22:45:30'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.68,
#   'Lng': 156.12,
#   'Max Temp': 48.29,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 16.75,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:45:30'},
#  {'City': 'Grootfontein',
#   'Lat': -19.57,
#   'Lng': 18.12,
#   'Max Temp': 43.97,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Country': 'NA',
#   'Date': '2020-07-08 22:45:31'},
#  {'City': 'Hamilton',
#   'Lat': 39.18,
#   'Lng': -84.53,
#   'Max Temp': 91.99,
#   'Humidity': 46,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Country': 'US',
#   'Date': '2020-07-08 22:40:50'},
#  {'City': 'Edeia',
#   'Lat': -17.34,
#   'Lng': -49.93,
#   'Max Temp': 71.17,
#   'Humidity': 38,
#   'Cloudiness': 61,
#   'Wind Speed': 3.56,
#   'Country': 'BR',
#   'Date': '2020-07-08 22:45:31'},
#  {'City': 'Nan',
#   'Lat': 18.83,
#   'Lng': 100.67,
#   'Max Temp': 72.55,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 0.85,
#   'Country': 'TH',
#   'Date': '2020-07-08 22:45:31'},
#  {'City': 'New Norfolk',
#   'Lat': -42.78,
#   'Lng': 147.06,
#   'Max Temp': 37,
#   'Humidity': 93,
#   'Cloudiness': 33,
#   'Wind Speed': 2.17,
#   'Country': 'AU',
#   'Date': '2020-07-08 22:45:31'},
#  {'City': 'Kruisfontein',
#   'Lat': -34,
#   'Lng': 24.73,
#   'Max Temp': 62.58,
#   'Humidity': 31,
#   'Cloudiness': 40,
#   'Wind Speed': 15.84,
#   'Country': 'ZA',
#   'Date': '2020-07-08 22:45:31'},
#  {'City': 'Wynyard',
#   'Lat': -41,
#   'Lng': 145.72,
#   'Max Temp': 45,
#   'Humidity': 91,
#   'Cloudiness': 83,
#   'Wind Speed': 1.99,
#   'Country': 'AU',
#   'Date': '2020-07-08 22:45:32'},
#  {'City': 'Jamestown',
#   'Lat': 42.1,
#   'Lng': -79.24,
#   'Max Temp': 84.99,
#   'Humidity': 62,
#   'Cloudiness': 1,
#   'Wind Speed': 5.82,
#   'Country': 'US',
#   'Date': '2020-07-08 22:45:32'},
#  {'City': 'Tabory',
#   'Lat': 58.52,
#   'Lng': 64.55,
#   'Max Temp': 67.3,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 5.32,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:45:32'},
#  {'City': 'Kashi',
#   'Lat': 39.45,
#   'Lng': 75.98,
#   'Max Temp': 78.8,
#   'Humidity': 22,
#   'Cloudiness': 40,
#   'Wind Speed': 8.95,
#   'Country': 'CN',
#   'Date': '2020-07-08 22:45:32'},
#  {'City': 'Nova Venecia',
#   'Lat': -18.71,
#   'Lng': -40.4,
#   'Max Temp': 67.68,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 3.29,
#   'Country': 'BR',
#   'Date': '2020-07-08 22:45:32'},
#  {'City': 'Mandalgovi',
#   'Lat': 45.76,
#   'Lng': 106.27,
#   'Max Temp': 66.87,
#   'Humidity': 44,
#   'Cloudiness': 41,
#   'Wind Speed': 4.79,
#   'Country': 'MN',
#   'Date': '2020-07-08 22:45:32'},
#  {'City': 'Horki',
#   'Lat': 54.29,
#   'Lng': 30.98,
#   'Max Temp': 51.66,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 5.73,
#   'Country': 'BY',
#   'Date': '2020-07-08 22:45:33'},
#  {'City': 'Pulaski',
#   'Lat': 34.77,
#   'Lng': -92.3,
#   'Max Temp': 89.01,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Country': 'US',
#   'Date': '2020-07-08 22:45:33'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.08,
#   'Max Temp': 84.24,
#   'Humidity': 70,
#   'Cloudiness': 27,
#   'Wind Speed': 4.88,
#   'Country': 'MV',
#   'Date': '2020-07-08 22:45:05'},
#  {'City': 'Trinidad',
#   'Lat': -14.83,
#   'Lng': -64.9,
#   'Max Temp': 69.48,
#   'Humidity': 91,
#   'Cloudiness': 61,
#   'Wind Speed': 5.84,
#   'Country': 'BO',
#   'Date': '2020-07-08 22:45:33'},
#  {'City': 'Bethel',
#   'Lat': 41.37,
#   'Lng': -73.41,
#   'Max Temp': 75.99,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Country': 'US',
#   'Date': '2020-07-08 22:45:33'},
#  {'City': 'East London',
#   'Lat': -33.02,
#   'Lng': 27.91,
#   'Max Temp': 71.06,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 13.96,
#   'Country': 'ZA',
#   'Date': '2020-07-08 22:45:33'},
#  {'City': 'Puerto Escondido',
#   'Lat': 15.85,
#   'Lng': -97.07,
#   'Max Temp': 86,
#   'Humidity': 66,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'MX',
#   'Date': '2020-07-08 22:45:33'},
#  {'City': 'Goodlettsville',
#   'Lat': 36.32,
#   'Lng': -86.71,
#   'Max Temp': 91.4,
#   'Humidity': 52,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Country': 'US',
#   'Date': '2020-07-08 22:45:05'},
#  {'City': 'College',
#   'Lat': 64.86,
#   'Lng': -147.8,
#   'Max Temp': 62.01,
#   'Humidity': 72,
#   'Cloudiness': 90,
#   'Wind Speed': 4.85,
#   'Country': 'US',
#   'Date': '2020-07-08 22:45:33'},
#  {'City': 'Huanren',
#   'Lat': 41.26,
#   'Lng': 125.37,
#   'Max Temp': 68.61,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 2.17,
#   'Country': 'CN',
#   'Date': '2020-07-08 22:45:33'},
#  {'City': 'Kismayo',
#   'Lat': -0.36,
#   'Lng': 42.55,
#   'Max Temp': 77.45,
#   'Humidity': 85,
#   'Cloudiness': 64,
#   'Wind Speed': 12.66,
#   'Country': 'SO',
#   'Date': '2020-07-08 22:45:34'},
#  {'City': 'Vardo',
#   'Lat': 70.37,
#   'Lng': 31.11,
#   'Max Temp': 50,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Country': 'NO',
#   'Date': '2020-07-08 22:45:34'},
#  {'City': 'Jumla',
#   'Lat': 29.27,
#   'Lng': 82.18,
#   'Max Temp': 60.28,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 1.74,
#   'Country': 'NP',
#   'Date': '2020-07-08 22:45:34'},
#  {'City': 'Oranjemund',
#   'Lat': -28.55,
#   'Lng': 16.43,
#   'Max Temp': 61.07,
#   'Humidity': 43,
#   'Cloudiness': 1,
#   'Wind Speed': 12.57,
#   'Country': 'NA',
#   'Date': '2020-07-08 22:45:19'},
#  {'City': 'Avarua',
#   'Lat': -21.21,
#   'Lng': -159.78,
#   'Max Temp': 78.8,
#   'Humidity': 61,
#   'Cloudiness': 68,
#   'Wind Speed': 19.46,
#   'Country': 'CK',
#   'Date': '2020-07-08 22:45:34'},
#  {'City': 'Puerto Rondon',
#   'Lat': 6.28,
#   'Lng': -71.1,
#   'Max Temp': 78.85,
#   'Humidity': 85,
#   'Cloudiness': 20,
#   'Wind Speed': 4.03,
#   'Country': 'CO',
#   'Date': '2020-07-08 22:45:34'},
#  {'City': 'Aranos',
#   'Lat': -24.13,
#   'Lng': 19.12,
#   'Max Temp': 58.21,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 18.9,
#   'Country': 'NA',
#   'Date': '2020-07-08 22:45:34'},
#  {'City': 'Pochutla',
#   'Lat': 15.74,
#   'Lng': -96.47,
#   'Max Temp': 91.99,
#   'Humidity': 52,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Country': 'MX',
#   'Date': '2020-07-08 22:45:34'},
#  {'City': 'Mananjary',
#   'Lat': -21.22,
#   'Lng': 48.33,
#   'Max Temp': 67.19,
#   'Humidity': 78,
#   'Cloudiness': 60,
#   'Wind Speed': 6.69,
#   'Country': 'MG',
#   'Date': '2020-07-08 22:45:34'},
#  {'City': 'Yulara',
#   'Lat': -25.24,
#   'Lng': 130.99,
#   'Max Temp': 41,
#   'Humidity': 52,
#   'Cloudiness': 50,
#   'Wind Speed': 6.93,
#   'Country': 'AU',
#   'Date': '2020-07-08 22:44:05'},
#  {'City': 'High Level',
#   'Lat': 58.52,
#   'Lng': -117.14,
#   'Max Temp': 68,
#   'Humidity': 52,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Country': 'CA',
#   'Date': '2020-07-08 22:45:34'},
#  {'City': 'Rio Grande',
#   'Lat': -32.03,
#   'Lng': -52.1,
#   'Max Temp': 50.72,
#   'Humidity': 91,
#   'Cloudiness': 97,
#   'Wind Speed': 20.42,
#   'Country': 'BR',
#   'Date': '2020-07-08 22:41:16'},
#  {'City': 'Tiksi',
#   'Lat': 71.69,
#   'Lng': 128.87,
#   'Max Temp': 34.65,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 4.9,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:45:11'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.92,
#   'Lng': 25.57,
#   'Max Temp': 62.6,
#   'Humidity': 45,
#   'Cloudiness': 18,
#   'Wind Speed': 12.75,
#   'Country': 'ZA',
#   'Date': '2020-07-08 22:45:23'},
#  {'City': 'Pangnirtung',
#   'Lat': 66.15,
#   'Lng': -65.71,
#   'Max Temp': 42.8,
#   'Humidity': 93,
#   'Cloudiness': 40,
#   'Wind Speed': 10.29,
#   'Country': 'CA',
#   'Date': '2020-07-08 22:45:34'},
#  {'City': 'Luwingu',
#   'Lat': -10.26,
#   'Lng': 29.93,
#   'Max Temp': 53.13,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 5.26,
#   'Country': 'ZM',
#   'Date': '2020-07-08 22:45:34'},
#  {'City': 'Hasaki',
#   'Lat': 35.73,
#   'Lng': 140.83,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'JP',
#   'Date': '2020-07-08 22:45:35'},
#  {'City': 'Kapaa',
#   'Lat': 22.08,
#   'Lng': -159.32,
#   'Max Temp': 82.4,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 20.8,
#   'Country': 'US',
#   'Date': '2020-07-08 22:45:35'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.03,
#   'Max Temp': 79.21,
#   'Humidity': 77,
#   'Cloudiness': 7,
#   'Wind Speed': 12.48,
#   'Country': 'PF',
#   'Date': '2020-07-08 22:45:35'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.34,
#   'Lng': 57.76,
#   'Max Temp': 69.8,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Country': 'MU',
#   'Date': '2020-07-08 22:45:35'},
#  {'City': 'Hermanus',
#   'Lat': -34.42,
#   'Lng': 19.23,
#   'Max Temp': 60.24,
#   'Humidity': 46,
#   'Cloudiness': 90,
#   'Wind Speed': 6.89,
#   'Country': 'ZA',
#   'Date': '2020-07-08 22:45:35'},
#  {'City': 'Zinder',
#   'Lat': 13.81,
#   'Lng': 8.99,
#   'Max Temp': 90.39,
#   'Humidity': 35,
#   'Cloudiness': 1,
#   'Wind Speed': 9.48,
#   'Country': 'NE',
#   'Date': '2020-07-08 22:45:35'},
#  {'City': 'Borogontsy',
#   'Lat': 62.67,
#   'Lng': 131.17,
#   'Max Temp': 69.15,
#   'Humidity': 49,
#   'Cloudiness': 59,
#   'Wind Speed': 3.51,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:45:35'},
#  {'City': 'Perpignan',
#   'Lat': 42.75,
#   'Lng': 2.75,
#   'Max Temp': 75,
#   'Humidity': 56,
#   'Cloudiness': 27,
#   'Wind Speed': 6.93,
#   'Country': 'FR',
#   'Date': '2020-07-08 22:45:35'},
#  {'City': 'Tangi',
#   'Lat': 34.3,
#   'Lng': 71.65,
#   'Max Temp': 86,
#   'Humidity': 42,
#   'Cloudiness': 75,
#   'Wind Speed': 20.8,
#   'Country': 'PK',
#   'Date': '2020-07-08 22:45:35'},
#  {'City': 'Guiratinga',
#   'Lat': -16.35,
#   'Lng': -53.76,
#   'Max Temp': 74.26,
#   'Humidity': 44,
#   'Cloudiness': 6,
#   'Wind Speed': 3.33,
#   'Country': 'BR',
#   'Date': '2020-07-08 22:45:35'},
#  {'City': 'Maceio',
#   'Lat': -9.67,
#   'Lng': -35.74,
#   'Max Temp': 73.4,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 2.24,
#   'Country': 'BR',
#   'Date': '2020-07-08 22:41:48'},
#  {'City': 'Kieta',
#   'Lat': -6.22,
#   'Lng': 155.63,
#   'Max Temp': 85.06,
#   'Humidity': 63,
#   'Cloudiness': 29,
#   'Wind Speed': 4.09,
#   'Country': 'PG',
#   'Date': '2020-07-08 22:45:32'},
#  {'City': 'Jurm',
#   'Lat': 36.86,
#   'Lng': 70.83,
#   'Max Temp': 68.68,
#   'Humidity': 36,
#   'Cloudiness': 77,
#   'Wind Speed': 3.53,
#   'Country': 'AF',
#   'Date': '2020-07-08 22:45:35'},
#  {'City': 'Kokkola',
#   'Lat': 63.84,
#   'Lng': 23.13,
#   'Max Temp': 55,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 2.24,
#   'Country': 'FI',
#   'Date': '2020-07-08 22:45:35'},
#  {'City': 'Carnarvon',
#   'Lat': -24.87,
#   'Lng': 113.63,
#   'Max Temp': 51.8,
#   'Humidity': 81,
#   'Cloudiness': 1,
#   'Wind Speed': 9.17,
#   'Country': 'AU',
#   'Date': '2020-07-08 22:43:26'},
#  {'City': 'Karratha',
#   'Lat': -20.74,
#   'Lng': 116.85,
#   'Max Temp': 64.58,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 10.65,
#   'Country': 'AU',
#   'Date': '2020-07-08 22:45:36'},
#  {'City': 'Kyshtovka',
#   'Lat': 56.55,
#   'Lng': 76.63,
#   'Max Temp': 65.05,
#   'Humidity': 85,
#   'Cloudiness': 24,
#   'Wind Speed': 8.61,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:45:36'},
#  {'City': 'Hegang',
#   'Lat': 47.4,
#   'Lng': 130.37,
#   'Max Temp': 66.36,
#   'Humidity': 83,
#   'Cloudiness': 38,
#   'Wind Speed': 4.56,
#   'Country': 'CN',
#   'Date': '2020-07-08 22:45:36'},
#  {'City': 'Nishihara',
#   'Lat': 26.18,
#   'Lng': 127.76,
#   'Max Temp': 84.2,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Country': 'JP',
#   'Date': '2020-07-08 22:45:36'},
#  {'City': 'Tucuman',
#   'Lat': -26.82,
#   'Lng': -65.22,
#   'Max Temp': 57.2,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Country': 'AR',
#   'Date': '2020-07-08 22:45:36'},
#  {'City': 'Dingle',
#   'Lat': 11,
#   'Lng': 122.67,
#   'Max Temp': 80.46,
#   'Humidity': 81,
#   'Cloudiness': 97,
#   'Wind Speed': 2.15,
#   'Country': 'PH',
#   'Date': '2020-07-08 22:45:36'},
#  {'City': 'Fortuna',
#   'Lat': 40.6,
#   'Lng': -124.16,
#   'Max Temp': 68,
#   'Humidity': 72,
#   'Cloudiness': 20,
#   'Wind Speed': 17.22,
#   'Country': 'US',
#   'Date': '2020-07-08 22:45:36'},
#  {'City': 'Machelen',
#   'Lat': 50.91,
#   'Lng': 4.44,
#   'Max Temp': 62.01,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'BE',
#   'Date': '2020-07-08 22:45:03'},
#  {'City': 'Ilebo',
#   'Lat': -4.32,
#   'Lng': 20.58,
#   'Max Temp': 75.88,
#   'Humidity': 54,
#   'Cloudiness': 42,
#   'Wind Speed': 0.38,
#   'Country': 'CD',
#   'Date': '2020-07-08 22:45:36'},
#  {'City': 'Okato',
#   'Lat': -39.2,
#   'Lng': 173.88,
#   'Max Temp': 54,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 5.99,
#   'Country': 'NZ',
#   'Date': '2020-07-08 22:45:36'},
#  {'City': 'Loandjili',
#   'Lat': -4.76,
#   'Lng': 11.86,
#   'Max Temp': 71.6,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 3.67,
#   'Country': 'CG',
#   'Date': '2020-07-08 22:45:36'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7,
#   'Lng': 30.79,
#   'Max Temp': 55.4,
#   'Humidity': 82,
#   'Cloudiness': 20,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:45:36'},
#  {'City': 'Mirabela',
#   'Lat': -16.26,
#   'Lng': -44.16,
#   'Max Temp': 64.04,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 1.81,
#   'Country': 'BR',
#   'Date': '2020-07-08 22:45:36'},
#  {'City': 'Gazanjyk',
#   'Lat': 39.24,
#   'Lng': 55.52,
#   'Max Temp': 85.41,
#   'Humidity': 16,
#   'Cloudiness': 0,
#   'Wind Speed': 5.21,
#   'Country': 'TM',
#   'Date': '2020-07-08 22:45:36'},
#  {'City': 'Altamira',
#   'Lat': -3.2,
#   'Lng': -52.21,
#   'Max Temp': 73.83,
#   'Humidity': 93,
#   'Cloudiness': 41,
#   'Wind Speed': 1.48,
#   'Country': 'BR',
#   'Date': '2020-07-08 22:45:36'},
#  {'City': 'Atasu',
#   'Lat': 48.68,
#   'Lng': 71.64,
#   'Max Temp': 63.48,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 10.67,
#   'Country': 'KZ',
#   'Date': '2020-07-08 22:45:26'},
#  {'City': 'San Cristobal',
#   'Lat': 7.77,
#   'Lng': -72.22,
#   'Max Temp': 89.6,
#   'Humidity': 55,
#   'Cloudiness': 40,
#   'Wind Speed': 9.17,
#   'Country': 'VE',
#   'Date': '2020-07-08 22:40:37'},
#  {'City': 'Tura',
#   'Lat': 25.52,
#   'Lng': 90.22,
#   'Max Temp': 75.24,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 5.66,
#   'Country': 'IN',
#   'Date': '2020-07-08 22:45:36'},
#  {'City': 'Fort Frances',
#   'Lat': 48.6,
#   'Lng': -93.4,
#   'Max Temp': 84.99,
#   'Humidity': 58,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Country': 'CA',
#   'Date': '2020-07-08 22:45:37'},
#  {'City': 'Ampanihy',
#   'Lat': -24.7,
#   'Lng': 44.75,
#   'Max Temp': 62.55,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 13.18,
#   'Country': 'MG',
#   'Date': '2020-07-08 22:45:37'},
#  {'City': 'San Quintin',
#   'Lat': 30.48,
#   'Lng': -115.95,
#   'Max Temp': 72.99,
#   'Humidity': 64,
#   'Cloudiness': 1,
#   'Wind Speed': 15.26,
#   'Country': 'MX',
#   'Date': '2020-07-08 22:45:37'},
#  {'City': 'Provideniya',
#   'Lat': 64.38,
#   'Lng': -173.3,
#   'Max Temp': 46.4,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:45:37'},
#  {'City': 'Nola',
#   'Lat': 40.92,
#   'Lng': 14.53,
#   'Max Temp': 73,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 2.57,
#   'Country': 'IT',
#   'Date': '2020-07-08 22:45:37'},
#  {'City': 'Kahului',
#   'Lat': 20.89,
#   'Lng': -156.47,
#   'Max Temp': 87.8,
#   'Humidity': 48,
#   'Cloudiness': 20,
#   'Wind Speed': 25.28,
#   'Country': 'US',
#   'Date': '2020-07-08 22:44:59'},
#  {'City': 'Camacupa',
#   'Lat': -12.02,
#   'Lng': 17.48,
#   'Max Temp': 51.71,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 3.38,
#   'Country': 'AO',
#   'Date': '2020-07-08 22:45:37'},
#  {'City': 'Navrongo',
#   'Lat': 10.9,
#   'Lng': -1.09,
#   'Max Temp': 81.12,
#   'Humidity': 72,
#   'Cloudiness': 27,
#   'Wind Speed': 8.16,
#   'Country': 'GH',
#   'Date': '2020-07-08 22:45:37'},
#  {'City': 'Qaqortoq',
#   'Lat': 60.72,
#   'Lng': -46.03,
#   'Max Temp': 55.4,
#   'Humidity': 54,
#   'Cloudiness': 99,
#   'Wind Speed': 3.36,
#   'Country': 'GL',
#   'Date': '2020-07-08 22:45:37'},
#  {'City': 'Kashin',
#   'Lat': 57.36,
#   'Lng': 37.61,
#   'Max Temp': 53.28,
#   'Humidity': 95,
#   'Cloudiness': 96,
#   'Wind Speed': 11.61,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:45:37'},
#  {'City': 'Pisco',
#   'Lat': -13.7,
#   'Lng': -76.22,
#   'Max Temp': 66.2,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 24.16,
#   'Country': 'PE',
#   'Date': '2020-07-08 22:43:30'},
#  {'City': 'Muskegon',
#   'Lat': 43.3,
#   'Lng': -86.13,
#   'Max Temp': 89.6,
#   'Humidity': 45,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2020-07-08 22:41:36'},
#  {'City': 'Te Anau',
#   'Lat': -45.42,
#   'Lng': 167.72,
#   'Max Temp': 40.73,
#   'Humidity': 86,
#   'Cloudiness': 69,
#   'Wind Speed': 0.83,
#   'Country': 'NZ',
#   'Date': '2020-07-08 22:45:37'},
#  {'City': 'Port Arthur',
#   'Lat': 38.8,
#   'Lng': 121.27,
#   'Max Temp': 69.8,
#   'Humidity': 73,
#   'Cloudiness': 82,
#   'Wind Speed': 2.24,
#   'Country': 'CN',
#   'Date': '2020-07-08 22:45:37'},
#  {'City': 'Aki',
#   'Lat': 33.5,
#   'Lng': 133.9,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Country': 'JP',
#   'Date': '2020-07-08 22:45:37'},
#  {'City': 'Santa Isabel',
#   'Lat': -23.32,
#   'Lng': -46.22,
#   'Max Temp': 73.4,
#   'Humidity': 46,
#   'Cloudiness': 34,
#   'Wind Speed': 4.7,
#   'Country': 'BR',
#   'Date': '2020-07-08 22:45:37'},
#  {'City': 'Sao Gabriel Da Cachoeira',
#   'Lat': -0.13,
#   'Lng': -67.09,
#   'Max Temp': 75.34,
#   'Humidity': 93,
#   'Cloudiness': 73,
#   'Wind Speed': 1.16,
#   'Country': 'BR',
#   'Date': '2020-07-08 22:45:37'},
#  {'City': 'Waingapu',
#   'Lat': -9.66,
#   'Lng': 120.26,
#   'Max Temp': 74.44,
#   'Humidity': 79,
#   'Cloudiness': 26,
#   'Wind Speed': 11.32,
#   'Country': 'ID',
#   'Date': '2020-07-08 22:45:38'},
#  {'City': 'Batemans Bay',
#   'Lat': -35.72,
#   'Lng': 150.18,
#   'Max Temp': 46.99,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 2.84,
#   'Country': 'AU',
#   'Date': '2020-07-08 22:45:38'},
#  {'City': 'Sabang',
#   'Lat': 5.89,
#   'Lng': 95.32,
#   'Max Temp': 82.85,
#   'Humidity': 65,
#   'Cloudiness': 69,
#   'Wind Speed': 6.71,
#   'Country': 'ID',
#   'Date': '2020-07-08 22:45:38'},
#  {'City': 'Santa Rosa',
#   'Lat': 14.31,
#   'Lng': 121.11,
#   'Max Temp': 82.99,
#   'Humidity': 82,
#   'Cloudiness': 53,
#   'Wind Speed': 3,
#   'Country': 'PH',
#   'Date': '2020-07-08 22:43:05'},
#  {'City': 'Bilma',
#   'Lat': 18.69,
#   'Lng': 12.92,
#   'Max Temp': 90.09,
#   'Humidity': 30,
#   'Cloudiness': 91,
#   'Wind Speed': 8.55,
#   'Country': 'NE',
#   'Date': '2020-07-08 22:45:38'},
#  {'City': 'Orneta',
#   'Lat': 54.11,
#   'Lng': 20.13,
#   'Max Temp': 47.84,
#   'Humidity': 90,
#   'Cloudiness': 1,
#   'Wind Speed': 6.69,
#   'Country': 'PL',
#   'Date': '2020-07-08 22:45:38'},
#  {'City': 'Kyritz',
#   'Lat': 52.94,
#   'Lng': 12.4,
#   'Max Temp': 57.99,
#   'Humidity': 77,
#   'Cloudiness': 83,
#   'Wind Speed': 5.26,
#   'Country': 'DE',
#   'Date': '2020-07-08 22:45:38'},
#  {'City': 'Victoria',
#   'Lat': 22.29,
#   'Lng': 114.16,
#   'Max Temp': 86,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 8.99,
#   'Country': 'HK',
#   'Date': '2020-07-08 22:41:24'},
#  {'City': 'Samarai',
#   'Lat': -10.62,
#   'Lng': 150.67,
#   'Max Temp': 78.62,
#   'Humidity': 87,
#   'Cloudiness': 85,
#   'Wind Speed': 21,
#   'Country': 'PG',
#   'Date': '2020-07-08 22:45:38'},
#  {'City': 'Karasburg',
#   'Lat': -28.02,
#   'Lng': 18.75,
#   'Max Temp': 60.24,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 13.22,
#   'Country': 'NA',
#   'Date': '2020-07-08 22:45:38'},
#  {'City': 'Dukat',
#   'Lat': 62.55,
#   'Lng': 155.55,
#   'Max Temp': 48.22,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 7.52,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:45:38'},
#  {'City': 'Boyabat',
#   'Lat': 41.47,
#   'Lng': 34.77,
#   'Max Temp': 63.66,
#   'Humidity': 78,
#   'Cloudiness': 38,
#   'Wind Speed': 3.67,
#   'Country': 'TR',
#   'Date': '2020-07-08 22:45:38'},
#  {'City': 'Hofn',
#   'Lat': 64.25,
#   'Lng': -15.21,
#   'Max Temp': 56.01,
#   'Humidity': 62,
#   'Cloudiness': 9,
#   'Wind Speed': 8.99,
#   'Country': 'IS',
#   'Date': '2020-07-08 22:45:38'},
#  {'City': 'Moree',
#   'Lat': -29.47,
#   'Lng': 149.85,
#   'Max Temp': 48.2,
#   'Humidity': 81,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Date': '2020-07-08 22:45:38'},
#  {'City': 'Kearney',
#   'Lat': 40.7,
#   'Lng': -99.08,
#   'Max Temp': 93.2,
#   'Humidity': 46,
#   'Cloudiness': 1,
#   'Wind Speed': 20.8,
#   'Country': 'US',
#   'Date': '2020-07-08 22:45:39'},
#  {'City': 'Mahajanga',
#   'Lat': -15.72,
#   'Lng': 46.32,
#   'Max Temp': 75.24,
#   'Humidity': 67,
#   'Cloudiness': 15,
#   'Wind Speed': 7.83,
#   'Country': 'MG',
#   'Date': '2020-07-08 22:45:39'},
#  {'City': 'Kargala',
#   'Lat': 56.62,
#   'Lng': 83.96,
#   'Max Temp': 66,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 5.82,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:45:39'},
#  {'City': 'Yellowknife',
#   'Lat': 62.46,
#   'Lng': -114.35,
#   'Max Temp': 64.4,
#   'Humidity': 45,
#   'Cloudiness': 40,
#   'Wind Speed': 3.36,
#   'Country': 'CA',
#   'Date': '2020-07-08 22:40:44'},
#  {'City': 'Khatanga',
#   'Lat': 71.97,
#   'Lng': 102.5,
#   'Max Temp': 63.79,
#   'Humidity': 50,
#   'Cloudiness': 21,
#   'Wind Speed': 19.66,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:45:14'},
#  {'City': 'Yanam',
#   'Lat': 16.73,
#   'Lng': 82.22,
#   'Max Temp': 81.99,
#   'Humidity': 83,
#   'Cloudiness': 81,
#   'Wind Speed': 5.91,
#   'Country': 'IN',
#   'Date': '2020-07-08 22:45:39'},
#  {'City': 'Lipin Bor',
#   'Lat': 60.26,
#   'Lng': 37.98,
#   'Max Temp': 55.35,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 11.25,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:45:39'},
#  {'City': 'Komsomolskiy',
#   'Lat': 40.43,
#   'Lng': 71.72,
#   'Max Temp': 77,
#   'Humidity': 36,
#   'Cloudiness': 91,
#   'Wind Speed': 11.41,
#   'Country': 'UZ',
#   'Date': '2020-07-08 22:45:39'},
#  {'City': 'Worland',
#   'Lat': 44.02,
#   'Lng': -107.96,
#   'Max Temp': 87.8,
#   'Humidity': 14,
#   'Cloudiness': 1,
#   'Wind Speed': 10.29,
#   'Country': 'US',
#   'Date': '2020-07-08 22:45:39'},
#  {'City': 'Statesboro',
#   'Lat': 32.45,
#   'Lng': -81.78,
#   'Max Temp': 86,
#   'Humidity': 58,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2020-07-08 22:45:39'},
#  {'City': 'Volax',
#   'Lat': 41.32,
#   'Lng': 24,
#   'Max Temp': 66.99,
#   'Humidity': 87,
#   'Cloudiness': 12,
#   'Wind Speed': 3.24,
#   'Country': 'GR',
#   'Date': '2020-07-08 22:45:39'},
#  {'City': 'Tautira',
#   'Lat': -17.73,
#   'Lng': -149.15,
#   'Max Temp': 82.4,
#   'Humidity': 58,
#   'Cloudiness': 20,
#   'Wind Speed': 12.75,
#   'Country': 'PF',
#   'Date': '2020-07-08 22:45:39'},
#  {'City': 'Canavieiras',
#   'Lat': -15.68,
#   'Lng': -38.95,
#   'Max Temp': 70.45,
#   'Humidity': 81,
#   'Cloudiness': 1,
#   'Wind Speed': 3.02,
#   'Country': 'BR',
#   'Date': '2020-07-08 22:45:39'},
#  {'City': 'Praya',
#   'Lat': 14.92,
#   'Lng': -23.51,
#   'Max Temp': 80.6,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'CV',
#   'Date': '2020-07-08 22:45:39'},
#  {'City': 'Sur',
#   'Lat': 22.57,
#   'Lng': 59.53,
#   'Max Temp': 85.5,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 12.55,
#   'Country': 'OM',
#   'Date': '2020-07-08 22:45:40'},
#  {'City': 'Waddan',
#   'Lat': 29.16,
#   'Lng': 16.14,
#   'Max Temp': 75.22,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 10.13,
#   'Country': 'LY',
#   'Date': '2020-07-08 22:45:40'},
#  {'City': 'Kosa',
#   'Lat': 59.94,
#   'Lng': 55,
#   'Max Temp': 67.91,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 4.9,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:45:40'},
#  {'City': 'Pevek',
#   'Lat': 69.7,
#   'Lng': 170.31,
#   'Max Temp': 46,
#   'Humidity': 73,
#   'Cloudiness': 51,
#   'Wind Speed': 0.89,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:45:40'},
#  {'City': 'Tapes',
#   'Lat': -30.67,
#   'Lng': -51.4,
#   'Max Temp': 51.93,
#   'Humidity': 88,
#   'Cloudiness': 96,
#   'Wind Speed': 11.92,
#   'Country': 'BR',
#   'Date': '2020-07-08 22:45:40'},
#  {'City': 'Santa Cruz',
#   'Lat': -17.8,
#   'Lng': -63.17,
#   'Max Temp': 55.4,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Country': 'BO',
#   'Date': '2020-07-08 22:41:36'},
#  {'City': 'Shelburne',
#   'Lat': 44.08,
#   'Lng': -80.2,
#   'Max Temp': 89.01,
#   'Humidity': 45,
#   'Cloudiness': 1,
#   'Wind Speed': 10.29,
#   'Country': 'CA',
#   'Date': '2020-07-08 22:41:24'},
#  {'City': 'Pecos',
#   'Lat': 31.42,
#   'Lng': -103.49,
#   'Max Temp': 104,
#   'Humidity': 16,
#   'Cloudiness': 1,
#   'Wind Speed': 3.36,
#   'Country': 'US',
#   'Date': '2020-07-08 22:45:40'},
#  {'City': 'Chuy',
#   'Lat': -33.7,
#   'Lng': -53.46,
#   'Max Temp': 47.21,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 18.43,
#   'Country': 'UY',
#   'Date': '2020-07-08 22:45:40'},
#  {'City': 'Nantucket',
#   'Lat': 41.28,
#   'Lng': -70.1,
#   'Max Temp': 73.99,
#   'Humidity': 88,
#   'Cloudiness': 1,
#   'Wind Speed': 11.41,
#   'Country': 'US',
#   'Date': '2020-07-08 22:44:51'},
#  {'City': 'Ostrovnoy',
#   'Lat': 68.05,
#   'Lng': 39.51,
#   'Max Temp': 53.19,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 4.43,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:45:40'},
#  {'City': 'Esperance',
#   'Lat': -33.87,
#   'Lng': 121.9,
#   'Max Temp': 48.2,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Country': 'AU',
#   'Date': '2020-07-08 22:45:15'},
#  {'City': 'Miles City',
#   'Lat': 46.41,
#   'Lng': -105.84,
#   'Max Temp': 80.6,
#   'Humidity': 28,
#   'Cloudiness': 20,
#   'Wind Speed': 19.46,
#   'Country': 'US',
#   'Date': '2020-07-08 22:45:40'},
#  {'City': 'Alexandria',
#   'Lat': 31.22,
#   'Lng': 29.96,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 9.17,
#   'Country': 'EG',
#   'Date': '2020-07-08 22:45:40'},
#  {'City': 'Crestview',
#   'Lat': 30.76,
#   'Lng': -86.57,
#   'Max Temp': 84.2,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 14.99,
#   'Country': 'US',
#   'Date': '2020-07-08 22:45:40'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.63,
#   'Lng': 147.92,
#   'Max Temp': 48.61,
#   'Humidity': 77,
#   'Cloudiness': 96,
#   'Wind Speed': 7.52,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:45:40'},
#  {'City': 'Meulaboh',
#   'Lat': 4.14,
#   'Lng': 96.13,
#   'Max Temp': 75.11,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 9.4,
#   'Country': 'ID',
#   'Date': '2020-07-08 22:45:40'},
#  {'City': 'Bonavista',
#   'Lat': 48.65,
#   'Lng': -53.11,
#   'Max Temp': 53.01,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 4,
#   'Country': 'CA',
#   'Date': '2020-07-08 22:45:40'},
#  {'City': 'Saldanha',
#   'Lat': -33.01,
#   'Lng': 17.94,
#   'Max Temp': 57.2,
#   'Humidity': 58,
#   'Cloudiness': 51,
#   'Wind Speed': 6.93,
#   'Country': 'ZA',
#   'Date': '2020-07-08 22:45:41'},
#  {'City': 'Olafsvik',
#   'Lat': 64.89,
#   'Lng': -23.71,
#   'Max Temp': 48.94,
#   'Humidity': 73,
#   'Cloudiness': 17,
#   'Wind Speed': 12.21,
#   'Country': 'IS',
#   'Date': '2020-07-08 22:45:41'},
#  {'City': 'Mandera',
#   'Lat': 3.94,
#   'Lng': 41.87,
#   'Max Temp': 80.71,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 17.87,
#   'Country': 'KE',
#   'Date': '2020-07-08 22:45:41'},
#  {'City': 'Goderich',
#   'Lat': 43.75,
#   'Lng': -81.72,
#   'Max Temp': 78.01,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 4.09,
#   'Country': 'CA',
#   'Date': '2020-07-08 22:45:41'},
#  {'City': 'Sarkand',
#   'Lat': 45.41,
#   'Lng': 79.92,
#   'Max Temp': 60.94,
#   'Humidity': 53,
#   'Cloudiness': 49,
#   'Wind Speed': 3.09,
#   'Country': 'KZ',
#   'Date': '2020-07-08 22:45:41'},
#  {'City': 'Antofagasta',
#   'Lat': -23.65,
#   'Lng': -70.4,
#   'Max Temp': 59,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 11.41,
#   'Country': 'CL',
#   'Date': '2020-07-08 22:43:59'},
#  {'City': 'Marsabit',
#   'Lat': 2.33,
#   'Lng': 37.99,
#   'Max Temp': 67.32,
#   'Humidity': 72,
#   'Cloudiness': 95,
#   'Wind Speed': 24.05,
#   'Country': 'KE',
#   'Date': '2020-07-08 22:45:41'},
#  {'City': 'Bubaque',
#   'Lat': 11.28,
#   'Lng': -15.83,
#   'Max Temp': 82.71,
#   'Humidity': 85,
#   'Cloudiness': 88,
#   'Wind Speed': 19.57,
#   'Country': 'GW',
#   'Date': '2020-07-08 22:45:41'},
#  {'City': 'Gambela',
#   'Lat': 8.25,
#   'Lng': 34.58,
#   'Max Temp': 68.74,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 3.15,
#   'Country': 'ET',
#   'Date': '2020-07-08 22:45:41'},
#  {'City': 'Hambantota',
#   'Lat': 6.12,
#   'Lng': 81.12,
#   'Max Temp': 78.8,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 3.36,
#   'Country': 'LK',
#   'Date': '2020-07-08 22:41:57'},
#  {'City': 'Lekoni',
#   'Lat': -1.58,
#   'Lng': 14.26,
#   'Max Temp': 79.95,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 1.66,
#   'Country': 'GA',
#   'Date': '2020-07-08 22:45:23'},
#  {'City': 'Lodja',
#   'Lat': -3.48,
#   'Lng': 23.43,
#   'Max Temp': 75.13,
#   'Humidity': 59,
#   'Cloudiness': 8,
#   'Wind Speed': 1.54,
#   'Country': 'CD',
#   'Date': '2020-07-08 22:45:41'},
#  {'City': 'Gazojak',
#   'Lat': 41.19,
#   'Lng': 61.4,
#   'Max Temp': 80.1,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 6.98,
#   'Country': 'TM',
#   'Date': '2020-07-08 22:45:41'},
#  {'City': 'Honningsvag',
#   'Lat': 70.98,
#   'Lng': 25.97,
#   'Max Temp': 46.74,
#   'Humidity': 93,
#   'Cloudiness': 99,
#   'Wind Speed': 8.19,
#   'Country': 'NO',
#   'Date': '2020-07-08 22:45:41'},
#  {'City': 'Kulhudhuffushi',
#   'Lat': 6.62,
#   'Lng': 73.07,
#   'Max Temp': 82.72,
#   'Humidity': 75,
#   'Cloudiness': 97,
#   'Wind Speed': 9.84,
#   'Country': 'MV',
#   'Date': '2020-07-08 22:45:41'},
#  {'City': 'Sept-Iles',
#   'Lat': 50.2,
#   'Lng': -66.38,
#   'Max Temp': 64.99,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Country': 'CA',
#   'Date': '2020-07-08 22:43:36'},
#  {'City': 'Selikhino',
#   'Lat': 50.37,
#   'Lng': 137.5,
#   'Max Temp': 54.72,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 11.03,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:45:41'},
#  {'City': 'Roald',
#   'Lat': 62.58,
#   'Lng': 6.13,
#   'Max Temp': 50,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 11.41,
#   'Country': 'NO',
#   'Date': '2020-07-08 22:45:41'},
#  {'City': 'Basey',
#   'Lat': 11.28,
#   'Lng': 125.07,
#   'Max Temp': 79.16,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 0.83,
#   'Country': 'PH',
#   'Date': '2020-07-08 22:45:42'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38,
#   'Lng': -57.56,
#   'Max Temp': 46,
#   'Humidity': 86,
#   'Cloudiness': 52,
#   'Wind Speed': 5.82,
#   'Country': 'AR',
#   'Date': '2020-07-08 22:44:51'},
#  {'City': 'Saint-Augustin',
#   'Lat': 51.23,
#   'Lng': -58.65,
#   'Max Temp': 60.73,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 17.07,
#   'Country': 'CA',
#   'Date': '2020-07-08 22:45:42'},
#  {'City': 'Panjab',
#   'Lat': 34.39,
#   'Lng': 67.02,
#   'Max Temp': 52.39,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 3.51,
#   'Country': 'AF',
#   'Date': '2020-07-08 22:45:42'},
#  {'City': 'Farah',
#   'Lat': 32.5,
#   'Lng': 62.5,
#   'Max Temp': 69.85,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Country': 'AF',
#   'Date': '2020-07-08 22:45:42'},
#  {'City': 'Cordoba',
#   'Lat': -31.41,
#   'Lng': -64.18,
#   'Max Temp': 48,
#   'Humidity': 67,
#   'Cloudiness': 5,
#   'Wind Speed': 4.7,
#   'Country': 'AR',
#   'Date': '2020-07-08 22:42:27'},
#  {'City': 'Nanortalik',
#   'Lat': 60.14,
#   'Lng': -45.24,
#   'Max Temp': 44.49,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 3.53,
#   'Country': 'GL',
#   'Date': '2020-07-08 22:43:17'},
#  {'City': 'Oswego',
#   'Lat': 43.45,
#   'Lng': -76.15,
#   'Max Temp': 87.8,
#   'Humidity': 55,
#   'Cloudiness': 1,
#   'Wind Speed': 5.82,
#   'Country': 'US',
#   'Date': '2020-07-08 22:41:23'},
#  {'City': 'Berezovka',
#   'Lat': 53.72,
#   'Lng': 25.5,
#   'Max Temp': 49.15,
#   'Humidity': 95,
#   'Cloudiness': 67,
#   'Wind Speed': 4.99,
#   'Country': 'BY',
#   'Date': '2020-07-08 22:45:42'},
#  {'City': 'Cerrito',
#   'Lat': 6.84,
#   'Lng': -72.69,
# ...
#   'Country': 'RU',
#   'Date': '2020-07-08 22:45:57'},
#  {'City': 'Kavieng',
#   'Lat': -2.57,
#   'Lng': 150.8,
#   'Max Temp': 84.07,
#   'Humidity': 71,
#   'Cloudiness': 16,
#   'Wind Speed': 10.45,
#   'Country': 'PG',
#   'Date': '2020-07-08 22:45:14'},
#  {'City': 'Taltal',
#   'Lat': -25.4,
#   'Lng': -70.48,
#   'Max Temp': 59.38,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Country': 'CL',
#   'Date': '2020-07-08 22:45:57'},
#  {'City': 'La Ronge',
#   'Lat': 55.1,
#   'Lng': -105.28,
#   'Max Temp': 59,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 12.75,
#   'Country': 'CA',
#   'Date': '2020-07-08 22:45:57'},
#  {'City': 'Paita',
#   'Lat': -5.09,
#   'Lng': -81.11,
#   'Max Temp': 66.22,
#   'Humidity': 73,
#   'Cloudiness': 53,
#   'Wind Speed': 19.24,
#   'Country': 'PE',
#   'Date': '2020-07-08 22:45:57'},
#  {'City': 'Charlestown',
#   'Lat': -32.95,
#   'Lng': 151.67,
#   'Max Temp': 53.01,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 2.62,
#   'Country': 'AU',
#   'Date': '2020-07-08 22:44:37'},
#  {'City': 'Yushu',
#   'Lat': 44.8,
#   'Lng': 126.53,
#   'Max Temp': 68.95,
#   'Humidity': 65,
#   'Cloudiness': 30,
#   'Wind Speed': 6.6,
#   'Country': 'CN',
#   'Date': '2020-07-08 22:45:57'},
#  {'City': 'Faya',
#   'Lat': 18.39,
#   'Lng': 42.45,
#   'Max Temp': 69.8,
#   'Humidity': 52,
#   'Cloudiness': 79,
#   'Wind Speed': 1.72,
#   'Country': 'SA',
#   'Date': '2020-07-08 22:45:57'},
#  {'City': 'Ibotirama',
#   'Lat': -12.19,
#   'Lng': -43.22,
#   'Max Temp': 74.43,
#   'Humidity': 37,
#   'Cloudiness': 1,
#   'Wind Speed': 2.37,
#   'Country': 'BR',
#   'Date': '2020-07-08 22:45:57'},
#  {'City': 'Talnakh',
#   'Lat': 69.49,
#   'Lng': 88.4,
#   'Max Temp': 51.8,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 22.37,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:45:57'},
#  {'City': 'Ibra',
#   'Lat': 22.69,
#   'Lng': 58.53,
#   'Max Temp': 82.98,
#   'Humidity': 63,
#   'Cloudiness': 81,
#   'Wind Speed': 2.71,
#   'Country': 'OM',
#   'Date': '2020-07-08 22:45:57'},
#  {'City': 'Lithakia',
#   'Lat': 37.72,
#   'Lng': 20.83,
#   'Max Temp': 69.8,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Country': 'GR',
#   'Date': '2020-07-08 22:45:58'},
#  {'City': 'Bahia Honda',
#   'Lat': 22.9,
#   'Lng': -83.16,
#   'Max Temp': 83.53,
#   'Humidity': 80,
#   'Cloudiness': 65,
#   'Wind Speed': 9.33,
#   'Country': 'CU',
#   'Date': '2020-07-08 22:45:58'},
#  {'City': 'Caibarien',
#   'Lat': 22.52,
#   'Lng': -79.47,
#   'Max Temp': 89.6,
#   'Humidity': 59,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Country': 'CU',
#   'Date': '2020-07-08 22:43:25'},
#  {'City': 'Magnolia',
#   'Lat': 33.27,
#   'Lng': -93.24,
#   'Max Temp': 87.8,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Country': 'US',
#   'Date': '2020-07-08 22:45:58'},
#  {'City': 'Palmer',
#   'Lat': 42.16,
#   'Lng': -72.33,
#   'Max Temp': 80.6,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Country': 'US',
#   'Date': '2020-07-08 22:45:58'},
#  {'City': 'Cururupu',
#   'Lat': -1.83,
#   'Lng': -44.87,
#   'Max Temp': 75.06,
#   'Humidity': 89,
#   'Cloudiness': 3,
#   'Wind Speed': 3.62,
#   'Country': 'BR',
#   'Date': '2020-07-08 22:45:58'},
#  {'City': 'Kerman',
#   'Lat': 30.28,
#   'Lng': 57.08,
#   'Max Temp': 64.4,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 2.75,
#   'Country': 'IR',
#   'Date': '2020-07-08 22:45:58'},
#  {'City': 'Bordighera',
#   'Lat': 43.78,
#   'Lng': 7.66,
#   'Max Temp': 73.4,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'IT',
#   'Date': '2020-07-08 22:45:58'},
#  {'City': 'Margate',
#   'Lat': 51.38,
#   'Lng': 1.39,
#   'Max Temp': 63,
#   'Humidity': 81,
#   'Cloudiness': 95,
#   'Wind Speed': 4,
#   'Country': 'GB',
#   'Date': '2020-07-08 22:45:58'},
#  {'City': 'Tirumullaivasal',
#   'Lat': 11.23,
#   'Lng': 79.83,
#   'Max Temp': 79.61,
#   'Humidity': 81,
#   'Cloudiness': 92,
#   'Wind Speed': 11.34,
#   'Country': 'IN',
#   'Date': '2020-07-08 22:45:58'},
#  {'City': 'Boguchany',
#   'Lat': 58.38,
#   'Lng': 97.45,
#   'Max Temp': 60.58,
#   'Humidity': 93,
#   'Cloudiness': 97,
#   'Wind Speed': 10.71,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:45:58'},
#  {'City': 'Gordeyevka',
#   'Lat': 52.96,
#   'Lng': 31.97,
#   'Max Temp': 51.87,
#   'Humidity': 92,
#   'Cloudiness': 59,
#   'Wind Speed': 7.7,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:45:58'},
#  {'City': 'Cam Ranh',
#   'Lat': 11.92,
#   'Lng': 109.16,
#   'Max Temp': 78.8,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 2.24,
#   'Country': 'VN',
#   'Date': '2020-07-08 22:45:58'},
#  {'City': 'Weatherford',
#   'Lat': 32.76,
#   'Lng': -97.8,
#   'Max Temp': 91.99,
#   'Humidity': 70,
#   'Cloudiness': 27,
#   'Wind Speed': 4,
#   'Country': 'US',
#   'Date': '2020-07-08 22:45:51'},
#  {'City': 'Great Yarmouth',
#   'Lat': 52.61,
#   'Lng': 1.73,
#   'Max Temp': 60.01,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'GB',
#   'Date': '2020-07-08 22:45:59'},
#  {'City': 'Scottsbluff',
#   'Lat': 41.87,
#   'Lng': -103.67,
#   'Max Temp': 93.2,
#   'Humidity': 26,
#   'Cloudiness': 1,
#   'Wind Speed': 4.7,
#   'Country': 'US',
#   'Date': '2020-07-08 22:45:59'},
#  {'City': 'Norman Wells',
#   'Lat': 65.28,
#   'Lng': -126.83,
#   'Max Temp': 68,
#   'Humidity': 37,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Country': 'CA',
#   'Date': '2020-07-08 22:45:59'},
#  {'City': 'Naze',
#   'Lat': 28.37,
#   'Lng': 129.48,
#   'Max Temp': 82.4,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 17.22,
#   'Country': 'JP',
#   'Date': '2020-07-08 22:45:59'},
#  {'City': 'Kaitangata',
#   'Lat': -46.28,
#   'Lng': 169.85,
#   'Max Temp': 45,
#   'Humidity': 73,
#   'Cloudiness': 69,
#   'Wind Speed': 8.01,
#   'Country': 'NZ',
#   'Date': '2020-07-08 22:45:59'},
#  {'City': 'Quatre Cocos',
#   'Lat': -20.21,
#   'Lng': 57.76,
#   'Max Temp': 69.8,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Country': 'MU',
#   'Date': '2020-07-08 22:45:59'},
#  {'City': 'Ometepec',
#   'Lat': 16.68,
#   'Lng': -98.42,
#   'Max Temp': 84.61,
#   'Humidity': 61,
#   'Cloudiness': 99,
#   'Wind Speed': 5.88,
#   'Country': 'MX',
#   'Date': '2020-07-08 22:45:59'},
#  {'City': 'Santa Luzia',
#   'Lat': -19.77,
#   'Lng': -43.85,
#   'Max Temp': 69.8,
#   'Humidity': 49,
#   'Cloudiness': 3,
#   'Wind Speed': 3.36,
#   'Country': 'BR',
#   'Date': '2020-07-08 22:45:59'},
#  {'City': 'Pokhara',
#   'Lat': 28.23,
#   'Lng': 83.98,
#   'Max Temp': 73.51,
#   'Humidity': 81,
#   'Cloudiness': 96,
#   'Wind Speed': 1.48,
#   'Country': 'NP',
#   'Date': '2020-07-08 22:45:59'},
#  {'City': 'Riyadh',
#   'Lat': 24.69,
#   'Lng': 46.72,
#   'Max Temp': 93.2,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'SA',
#   'Date': '2020-07-08 22:45:38'},
#  {'City': 'Merauke',
#   'Lat': -8.47,
#   'Lng': 140.33,
#   'Max Temp': 78.1,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 16.98,
#   'Country': 'ID',
#   'Date': '2020-07-08 22:45:59'},
#  {'City': 'Jacareacanga',
#   'Lat': -6.22,
#   'Lng': -57.75,
#   'Max Temp': 77.83,
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 2.01,
#   'Country': 'BR',
#   'Date': '2020-07-08 22:45:59'},
#  {'City': 'Olinda',
#   'Lat': -8.01,
#   'Lng': -34.86,
#   'Max Temp': 78.8,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 10.29,
#   'Country': 'BR',
#   'Date': '2020-07-08 22:45:59'},
#  {'City': 'Anloga',
#   'Lat': 5.79,
#   'Lng': 0.9,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 11.41,
#   'Country': 'GH',
#   'Date': '2020-07-08 22:46:00'},
#  {'City': 'Yatou',
#   'Lat': 37.15,
#   'Lng': 122.38,
#   'Max Temp': 71.58,
#   'Humidity': 67,
#   'Cloudiness': 69,
#   'Wind Speed': 2.06,
#   'Country': 'CN',
#   'Date': '2020-07-08 22:46:00'},
#  {'City': 'Toropets',
#   'Lat': 56.5,
#   'Lng': 31.64,
#   'Max Temp': 51.67,
#   'Humidity': 89,
#   'Cloudiness': 50,
#   'Wind Speed': 3.78,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:46:00'},
#  {'City': 'Necochea',
#   'Lat': -38.55,
#   'Lng': -58.74,
#   'Max Temp': 42.01,
#   'Humidity': 93,
#   'Cloudiness': 82,
#   'Wind Speed': 8.01,
#   'Country': 'AR',
#   'Date': '2020-07-08 22:46:00'},
#  {'City': 'Vostok',
#   'Lat': 46.49,
#   'Lng': 135.88,
#   'Max Temp': 55.72,
#   'Humidity': 100,
#   'Cloudiness': 99,
#   'Wind Speed': 3.69,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:46:00'},
#  {'City': 'Isla Mujeres',
#   'Lat': 21.23,
#   'Lng': -86.73,
#   'Max Temp': 87.8,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Country': 'MX',
#   'Date': '2020-07-08 22:46:00'},
#  {'City': 'Majalengka',
#   'Lat': -6.84,
#   'Lng': 108.23,
#   'Max Temp': 73.22,
#   'Humidity': 81,
#   'Cloudiness': 47,
#   'Wind Speed': 6.2,
#   'Country': 'ID',
#   'Date': '2020-07-08 22:46:00'},
#  {'City': 'Berlevag',
#   'Lat': 70.86,
#   'Lng': 29.09,
#   'Max Temp': 50.11,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 2.75,
#   'Country': 'NO',
#   'Date': '2020-07-08 22:46:00'},
#  {'City': 'Kralendijk',
#   'Lat': 12.15,
#   'Lng': -68.27,
#   'Max Temp': 84.2,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 20.8,
#   'Country': 'BQ',
#   'Date': '2020-07-08 22:46:00'},
#  {'City': 'Pandan',
#   'Lat': 14.05,
#   'Lng': 124.17,
#   'Max Temp': 83.01,
#   'Humidity': 76,
#   'Cloudiness': 71,
#   'Wind Speed': 3.53,
#   'Country': 'PH',
#   'Date': '2020-07-08 22:46:00'},
#  {'City': 'Lander',
#   'Lat': 42.83,
#   'Lng': -108.73,
#   'Max Temp': 86,
#   'Humidity': 9,
#   'Cloudiness': 1,
#   'Wind Speed': 18.34,
#   'Country': 'US',
#   'Date': '2020-07-08 22:46:00'},
#  {'City': 'Plettenberg Bay',
#   'Lat': -34.05,
#   'Lng': 23.37,
#   'Max Temp': 72.21,
#   'Humidity': 24,
#   'Cloudiness': 64,
#   'Wind Speed': 16.33,
#   'Country': 'ZA',
#   'Date': '2020-07-08 22:43:55'},
#  {'City': 'Tuatapere',
#   'Lat': -46.13,
#   'Lng': 167.68,
#   'Max Temp': 43.84,
#   'Humidity': 87,
#   'Cloudiness': 96,
#   'Wind Speed': 5.14,
#   'Country': 'NZ',
#   'Date': '2020-07-08 22:45:49'},
#  {'City': 'Elk',
#   'Lat': 53.83,
#   'Lng': 22.36,
#   'Max Temp': 48.24,
#   'Humidity': 94,
#   'Cloudiness': 11,
#   'Wind Speed': 5.44,
#   'Country': 'PL',
#   'Date': '2020-07-08 22:46:00'},
#  {'City': 'Torzhok',
#   'Lat': 57.04,
#   'Lng': 34.96,
#   'Max Temp': 50.99,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.84,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:46:00'},
#  {'City': 'Vila',
#   'Lat': 42.03,
#   'Lng': -8.16,
#   'Max Temp': 70,
#   'Humidity': 82,
#   'Cloudiness': 16,
#   'Wind Speed': 4.7,
#   'Country': 'PT',
#   'Date': '2020-07-08 22:44:04'},
#  {'City': 'Beaverlodge',
#   'Lat': 55.22,
#   'Lng': -119.44,
#   'Max Temp': 69.8,
#   'Humidity': 46,
#   'Cloudiness': 40,
#   'Wind Speed': 9.17,
#   'Country': 'CA',
#   'Date': '2020-07-08 22:46:00'},
#  {'City': 'Velikiy Ustyug',
#   'Lat': 60.76,
#   'Lng': 46.31,
#   'Max Temp': 76.1,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 8.59,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:46:00'},
#  {'City': 'Lincoln',
#   'Lat': 40.8,
#   'Lng': -96.67,
#   'Max Temp': 93,
#   'Humidity': 49,
#   'Cloudiness': 40,
#   'Wind Speed': 17.22,
#   'Country': 'US',
#   'Date': '2020-07-08 22:43:34'},
#  {'City': 'Porto Torres',
#   'Lat': 40.84,
#   'Lng': 8.4,
#   'Max Temp': 71.6,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 1.12,
#   'Country': 'IT',
#   'Date': '2020-07-08 22:46:01'},
#  {'City': 'Taoudenni',
#   'Lat': 22.68,
#   'Lng': -3.98,
#   'Max Temp': 96.51,
#   'Humidity': 9,
#   'Cloudiness': 0,
#   'Wind Speed': 17.72,
#   'Country': 'ML',
#   'Date': '2020-07-08 22:44:05'},
#  {'City': 'Madison',
#   'Lat': 34.73,
#   'Lng': -86.57,
#   'Max Temp': 84.99,
#   'Humidity': 78,
#   'Cloudiness': 1,
#   'Wind Speed': 5.41,
#   'Country': 'US',
#   'Date': '2020-07-08 22:44:35'},
#  {'City': 'Ozinki',
#   'Lat': 51.18,
#   'Lng': 49.68,
#   'Max Temp': 77.31,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 13.73,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:46:01'},
#  {'City': 'Vao',
#   'Lat': -22.67,
#   'Lng': 167.48,
#   'Max Temp': 69.1,
#   'Humidity': 60,
#   'Cloudiness': 49,
#   'Wind Speed': 14.54,
#   'Country': 'NC',
#   'Date': '2020-07-08 22:46:01'},
#  {'City': 'Praia',
#   'Lat': 14.92,
#   'Lng': -23.51,
#   'Max Temp': 80.6,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'CV',
#   'Date': '2020-07-08 22:46:01'},
#  {'City': 'Hluti',
#   'Lat': -27.22,
#   'Lng': 31.62,
#   'Max Temp': 60.8,
#   'Humidity': 82,
#   'Cloudiness': 24,
#   'Wind Speed': 3.36,
#   'Country': 'SZ',
#   'Date': '2020-07-08 22:46:01'},
#  {'City': 'Russell',
#   'Lat': 32.35,
#   'Lng': -85.2,
#   'Max Temp': 87.8,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7,
#   'Country': 'US',
#   'Date': '2020-07-08 22:46:01'},
#  {'City': 'Kifri',
#   'Lat': 34.7,
#   'Lng': 44.97,
#   'Max Temp': 91.6,
#   'Humidity': 13,
#   'Cloudiness': 1,
#   'Wind Speed': 7.92,
#   'Country': 'IQ',
#   'Date': '2020-07-08 22:46:01'},
#  {'City': 'Coihaique',
#   'Lat': -45.58,
#   'Lng': -72.07,
#   'Max Temp': 35.6,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'CL',
#   'Date': '2020-07-08 22:46:01'},
#  {'City': 'Matamoros',
#   'Lat': 25.53,
#   'Lng': -103.25,
#   'Max Temp': 96.8,
#   'Humidity': 26,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Country': 'MX',
#   'Date': '2020-07-08 22:45:31'},
#  {'City': 'Hirara',
#   'Lat': 24.8,
#   'Lng': 125.28,
#   'Max Temp': 84.2,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Country': 'JP',
#   'Date': '2020-07-08 22:46:01'},
#  {'City': 'Syracuse',
#   'Lat': 37.09,
#   'Lng': 15.28,
#   'Max Temp': 75.2,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Country': 'IT',
#   'Date': '2020-07-08 22:46:01'},
#  {'City': 'Usevya',
#   'Lat': -7.1,
#   'Lng': 31.23,
#   'Max Temp': 68.95,
#   'Humidity': 44,
#   'Cloudiness': 2,
#   'Wind Speed': 9.28,
#   'Country': 'TZ',
#   'Date': '2020-07-08 22:46:01'},
#  {'City': 'Nouadhibou',
#   'Lat': 20.93,
#   'Lng': -17.03,
#   'Max Temp': 71.6,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 23.04,
#   'Country': 'MR',
#   'Date': '2020-07-08 22:46:01'},
#  {'City': 'Port Hardy',
#   'Lat': 50.7,
#   'Lng': -127.42,
#   'Max Temp': 59,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 2.24,
#   'Country': 'CA',
#   'Date': '2020-07-08 22:46:01'},
#  {'City': 'Vytegra',
#   'Lat': 61.01,
#   'Lng': 36.45,
#   'Max Temp': 53.83,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 5.77,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:46:01'},
#  {'City': 'Eslamshahr',
#   'Lat': 35.56,
#   'Lng': 51.23,
#   'Max Temp': 82.4,
#   'Humidity': 28,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'IR',
#   'Date': '2020-07-08 22:46:01'},
#  {'City': 'Chernukha',
#   'Lat': 55.6,
#   'Lng': 43.76,
#   'Max Temp': 70.86,
#   'Humidity': 83,
#   'Cloudiness': 57,
#   'Wind Speed': 6.58,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:46:02'},
#  {'City': 'Clarence Town',
#   'Lat': -32.58,
#   'Lng': 151.78,
#   'Max Temp': 55,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 1.32,
#   'Country': 'AU',
#   'Date': '2020-07-08 22:46:02'},
#  {'City': 'Westport',
#   'Lat': 41.14,
#   'Lng': -73.36,
#   'Max Temp': 75.2,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82,
#   'Country': 'US',
#   'Date': '2020-07-08 22:42:10'},
#  {'City': 'Ginda',
#   'Lat': 30.69,
#   'Lng': 78.49,
#   'Max Temp': 64.24,
#   'Humidity': 84,
#   'Cloudiness': 62,
#   'Wind Speed': 2.42,
#   'Country': 'IN',
#   'Date': '2020-07-08 22:46:02'},
#  {'City': 'Borovskiy',
#   'Lat': 57.04,
#   'Lng': 65.72,
#   'Max Temp': 66.2,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 6.71,
#   'Country': 'RU',
#   'Date': '2020-07-08 22:46:02'},
#  {'City': 'Papenburg',
#   'Lat': 53.07,
#   'Lng': 7.4,
#   'Max Temp': 57.2,
#   'Humidity': 93,
#   'Cloudiness': 95,
#   'Wind Speed': 1.12,
#   'Country': 'DE',
#   'Date': '2020-07-08 22:46:02'},
#  {'City': 'Biak',
#   'Lat': -0.91,
#   'Lng': 122.88,
#   'Max Temp': 77.25,
#   'Humidity': 84,
#   'Cloudiness': 96,
#   'Wind Speed': 4.99,
#   'Country': 'ID',
#   'Date': '2020-07-08 22:46:02'},
#  {'City': 'Doka',
#   'Lat': 13.52,
#   'Lng': 35.77,
#   'Max Temp': 73.36,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 9.1,
#   'Country': 'SD',
#   'Date': '2020-07-08 22:46:02'},
#  {'City': 'Ifakara',
#   'Lat': -8.13,
#   'Lng': 36.68,
#   'Max Temp': 75,
#   'Humidity': 64,
#   'Cloudiness': 95,
#   'Wind Speed': 3.78,
#   'Country': 'TZ',
#   'Date': '2020-07-08 22:46:02'},
#  {'City': 'Parainen',
#   'Lat': 60.31,
#   'Lng': 22.3,
#   'Max Temp': 53.01,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Country': 'FI',
#   'Date': '2020-07-08 22:46:02'},
#  {'City': 'Achutupo',
#   'Lat': 9.2,
#   'Lng': -77.98,
#   'Max Temp': 81.5,
#   'Humidity': 81,
#   'Cloudiness': 93,
#   'Wind Speed': 5.21,
#   'Country': 'PA',
#   'Date': '2020-07-08 22:46:02'}]

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Cape Town -33.93   18.42     60.01        47          90        9.17
# 1   Kavaratti  10.57   72.64     83.71        73          99       17.43
# 2  Georgetown   5.41  100.34     77.00        94          20        1.12
# 3       Nagua  19.38  -69.85     75.20        94          75        7.23
# 4      Turbat  26.00   63.04     85.55        68          98        9.06
#
#   Country                 Date
# 0      ZA  2020-07-08 22:41:10
# 1      IN  2020-07-08 22:45:21
# 2      MY  2020-07-08 22:45:21
# 3      DO  2020-07-08 22:45:21
# 4      PK  2020-07-08 22:45:21

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Cape Town -33.93   18.42     60.01        47          90        9.17
# 1      Kavaratti  10.57   72.64     83.71        73          99       17.43
# 2     Georgetown   5.41  100.34     77.00        94          20        1.12
# 3          Nagua  19.38  -69.85     75.20        94          75        7.23
# 4         Turbat  26.00   63.04     85.55        68          98        9.06
# 5       La Rioja  42.25   -2.50     75.20        64         100        6.93
# 6          Bluff -46.60  168.33     48.18        80          81       13.98
# 7    Clyde River  70.47  -68.59     37.40        93          90        5.82
# 8  Leningradskiy  69.38  178.42     48.87        71           0       10.87
# 9         Lupiro  -8.38   36.67     73.56        66          94        4.94
#
#   Country                 Date
# 0      ZA  2020-07-08 22:41:10
# 1      IN  2020-07-08 22:45:21
# 2      MY  2020-07-08 22:45:21
# 3      DO  2020-07-08 22:45:21
# 4      PK  2020-07-08 22:45:21
# 5      ES  2020-07-08 22:43:39
# 6      NZ  2020-07-08 22:45:10
# 7      CA  2020-07-08 22:45:13
# 8      RU  2020-07-08 22:41:07
# 9      TZ  2020-07-08 22:45:21

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today
# Out:
# 1594248362.8805828

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.  
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                        Vaini
# Lat                         -21.2
# Lng                        -175.2
# Max Temp                       77
# Humidity                       78
# Cloudiness                     75
# Wind Speed                   5.82
# Country                        TO
# Date          2020-07-08 22:45:21
# Name: 13, dtype: object

# %%
city_data_df["Lat"] >= 0
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 575    False
# 576     True
# 577    False
# 578     True
# 579     True
# Name: Lat, Length: 580, dtype: bool

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)]
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 1     Kavaratti  10.57   72.64     83.71        73          99       17.43
# 2    Georgetown   5.41  100.34     77.00        94          20        1.12
# 3         Nagua  19.38  -69.85     75.20        94          75        7.23
# 4        Turbat  26.00   63.04     85.55        68          98        9.06
# 5      La Rioja  42.25   -2.50     75.20        64         100        6.93
# ..          ...    ...     ...       ...       ...         ...         ...
# 573   Borovskiy  57.04   65.72     66.20        82           0        6.71
# 574   Papenburg  53.07    7.40     57.20        93          95        1.12
# 576        Doka  13.52   35.77     73.36        88         100        9.10
# 578    Parainen  60.31   22.30     53.01        93          90        4.70
# 579    Achutupo   9.20  -77.98     81.50        81          93        5.21
#
#     Country                 Date
# 1        IN  2020-07-08 22:45:21
# 2        MY  2020-07-08 22:45:21
# 3        DO  2020-07-08 22:45:21
# 4        PK  2020-07-08 22:45:21
# 5        ES  2020-07-08 22:43:39
# ..      ...                  ...
# 573      RU  2020-07-08 22:46:02
# 574      DE  2020-07-08 22:46:02
# 576      SD  2020-07-08 22:46:02
# 578      FI  2020-07-08 22:46:02
# 579      PA  2020-07-08 22:46:02
#
# [393 rows x 9 columns]

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
northern_hemi_df
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 1     Kavaratti  10.57   72.64     83.71        73          99       17.43
# 2    Georgetown   5.41  100.34     77.00        94          20        1.12
# 3         Nagua  19.38  -69.85     75.20        94          75        7.23
# 4        Turbat  26.00   63.04     85.55        68          98        9.06
# 5      La Rioja  42.25   -2.50     75.20        64         100        6.93
# ..          ...    ...     ...       ...       ...         ...         ...
# 573   Borovskiy  57.04   65.72     66.20        82           0        6.71
# 574   Papenburg  53.07    7.40     57.20        93          95        1.12
# 576        Doka  13.52   35.77     73.36        88         100        9.10
# 578    Parainen  60.31   22.30     53.01        93          90        4.70
# 579    Achutupo   9.20  -77.98     81.50        81          93        5.21
#
#     Country                 Date
# 1        IN  2020-07-08 22:45:21
# 2        MY  2020-07-08 22:45:21
# 3        DO  2020-07-08 22:45:21
# 4        PK  2020-07-08 22:45:21
# 5        ES  2020-07-08 22:43:39
# ..      ...                  ...
# 573      RU  2020-07-08 22:46:02
# 574      DE  2020-07-08 22:46:02
# 576      SD  2020-07-08 22:46:02
# 578      FI  2020-07-08 22:46:02
# 579      PA  2020-07-08 22:46:02
#
# [393 rows x 9 columns]

# %%
southern_hemi_df
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Cape Town -33.93   18.42     60.01        47          90        9.17
# 6            Bluff -46.60  168.33     48.18        80          81       13.98
# 9           Lupiro  -8.38   36.67     73.56        66          94        4.94
# 11         Rikitea -23.12 -134.97     67.57        63          23       18.07
# 13           Vaini -21.20 -175.20     77.00        78          75        5.82
# ..             ...    ...     ...       ...       ...         ...         ...
# 560      Coihaique -45.58  -72.07     35.60        93          75        8.05
# 564         Usevya  -7.10   31.23     68.95        44           2        9.28
# 570  Clarence Town -32.58  151.78     55.00       100          40        1.32
# 575           Biak  -0.91  122.88     77.25        84          96        4.99
# 577        Ifakara  -8.13   36.68     75.00        64          95        3.78
#
#     Country                 Date
# 0        ZA  2020-07-08 22:41:10
# 6        NZ  2020-07-08 22:45:10
# 9        TZ  2020-07-08 22:45:21
# 11       PF  2020-07-08 22:45:03
# 13       TO  2020-07-08 22:45:21
# ..      ...                  ...
# 560      CL  2020-07-08 22:46:01
# 564      TZ  2020-07-08 22:46:01
# 570      AU  2020-07-08 22:46:02
# 575      ID  2020-07-08 22:46:02
# 577      TZ  2020-07-08 22:46:02
#
# [187 rows x 9 columns]

# %%
# !pip install gmaps
# Out:
# Requirement already satisfied: gmaps in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (0.9.0)
# Requirement already satisfied: traitlets>=4.3.0 in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from gmaps) (4.3.3)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from gmaps) (7.5.1)
# Requirement already satisfied: ipython>=5.3.0 in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from gmaps) (7.12.0)
# Requirement already satisfied: six in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from gmaps) (1.14.0)
# Requirement already satisfied: geojson>=2.0.0 in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from gmaps) (2.5.0)
# Requirement already satisfied: decorator in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from traitlets>=4.3.0->gmaps) (4.4.1)
# Requirement already satisfied: ipython-genutils in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from traitlets>=4.3.0->gmaps) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.0.0->gmaps) (5.0.4)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.0.0->gmaps) (5.1.4)
# Requirement already satisfied: pickleshare in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (46.0.0.post20200309)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (0.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (3.0.3)
# Requirement already satisfied: jedi>=0.10 in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (0.14.1)
# Requirement already satisfied: pygments in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (2.5.2)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (4.8.0)
# Requirement already satisfied: backcall in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from ipython>=5.3.0->gmaps) (0.1.0)
# Requirement already satisfied: notebook>=4.4.1 in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.0.3)
# Requirement already satisfied: jupyter-core in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.6.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.2.0)
# Requirement already satisfied: jupyter-client in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (5.3.4)
# Requirement already satisfied: tornado>=4.2 in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.0.3)
# Requirement already satisfied: wcwidth in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.1.8)
# Requirement already satisfied: parso>=0.5.0 in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from jedi>=0.10->ipython>=5.3.0->gmaps) (0.5.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=5.3.0->gmaps) (0.6.0)
# Requirement already satisfied: pyzmq>=17 in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (18.1.1)
# Requirement already satisfied: nbconvert in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (5.6.1)
# Requirement already satisfied: jinja2 in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.1)
# Requirement already satisfied: Send2Trash in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: terminado>=0.8.1 in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.3)
# Requirement already satisfied: prometheus-client in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.15.7)
# Requirement already satisfied: attrs>=17.4.0 in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (19.3.0)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.1)
# Requirement already satisfied: defusedxml in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.6.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: bleach in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.1.0)
# Requirement already satisfied: testpath in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: zipp>=0.5 in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (2.2.0)
# Requirement already satisfied: webencodings in /Users/shanicebrown/opt/anaconda3/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)

# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID        City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        0   Cape Town -33.93   18.42     60.01        47          90
# 1        1   Kavaratti  10.57   72.64     83.71        73          99
# 2        2  Georgetown   5.41  100.34     77.00        94          20
# 3        3       Nagua  19.38  -69.85     75.20        94          75
# 4        4      Turbat  26.00   63.04     85.55        68          98
#
#    Wind Speed Country                 Date
# 0        9.17      ZA  2020-07-08 22:41:10
# 1       17.43      IN  2020-07-08 22:45:21
# 2        1.12      MY  2020-07-08 22:45:21
# 3        7.23      DO  2020-07-08 22:45:21
# 4        9.06      PK  2020-07-08 22:45:21

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Country        object
# Date           object
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)
g_key
# Out:
# 'AIzaSyCe6HMbC5TEUe2Ao0CvWaHeS1DAPpfPvSU'

# %%
# 1. Assign the locations to an array of latitude and longitude pairs.
locations = city_data_df[["Lat" , "Lng"]]
# 2. Assign the weights variable to some values.
temperatures =  city_data_df["Max Temp"]
# 3. Assign the figure variable to the gmaps.figure() attribute.
fig = gmaps.figure()
# 4. Assign the heatmap_layer variable to the heatmap_layer attribute and add in the locations.
heatmap_layer = gmaps.heatmap_layer(locations, weights=temperatures)

# 5. Add the heatmap layer.
fig.add_layer(heatmap_layer)
# 6. Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure()
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID        City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 1         1   Kavaratti  10.57   72.64     83.71        73          99
# 2         2  Georgetown   5.41  100.34     77.00        94          20
# 3         3       Nagua  19.38  -69.85     75.20        94          75
# 4         4      Turbat  26.00   63.04     85.55        68          98
# 5         5    La Rioja  42.25   -2.50     75.20        64         100
# 10       10        Hilo  19.73 -155.09     82.40        65          90
# 13       13       Vaini -21.20 -175.20     77.00        78          75
# 17       17      Agadez  19.75   10.25     88.93        27          46
# 18       18      Albany  42.60  -73.97     77.00        80          64
# 19       19      Matara   5.95   80.54     79.34        86         100
#
#     Wind Speed Country                 Date
# 1        17.43      IN  2020-07-08 22:45:21
# 2         1.12      MY  2020-07-08 22:45:21
# 3         7.23      DO  2020-07-08 22:45:21
# 4         9.06      PK  2020-07-08 22:45:21
# 5         6.93      ES  2020-07-08 22:43:39
# 10       13.87      US  2020-07-08 22:45:21
# 13        5.82      TO  2020-07-08 22:45:21
# 17        8.68      NE  2020-07-08 22:45:22
# 18        3.53      US  2020-07-08 22:45:22
# 19       10.54      LK  2020-07-08 22:45:22

# %%
preferred_cities_df.count()
# Out:
# City_ID       203
# City          203
# Lat           203
# Lng           203
# Max Temp      203
# Humidity      203
# Cloudiness    203
# Wind Speed    203
# Country       203
# Date          203
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#           City Country  Max Temp    Lat     Lng Hotel Name
# 1    Kavaratti      IN     83.71  10.57   72.64
# 2   Georgetown      MY     77.00   5.41  100.34
# 3        Nagua      DO     75.20  19.38  -69.85
# 4       Turbat      PK     85.55  26.00   63.04
# 5     La Rioja      ES     75.20  42.25   -2.50
# 10        Hilo      US     82.40  19.73 -155.09
# 13       Vaini      TO     77.00 -21.20 -175.20
# 17      Agadez      NE     88.93  19.75   10.25
# 18      Albany      US     77.00  42.60  -73.97
# 19      Matara      LK     79.34   5.95   80.54

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %%
# Dependencies and Setup
import requests
import gmaps

# Import API key
from config import g_key

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-234-fb4b837962f0> in <module>
#      13     hotels = requests.get(base_url, params=params).json()
#      14     # Grab the first hotel from the results and store the name.
# ---> 15     hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
#
# IndexError: list index out of range

# %%
# Grab the first hotel from the results and store the name.
  try:
    hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
  except (IndexError):
    print("Hotel not found... skipping.")
# Out:
#   File "<ipython-input-235-0bcb6a2623ec>", line 2
#     try:
#     ^
# IndentationError: unexpected indent
